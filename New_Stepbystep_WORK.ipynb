# %% [markdown]
# CONVERSION FROM PDF TO XML

# %%
import os
import requests

# === Configuration ===
PDF_FOLDER = r"make-data-count-finding-data-references\train\PDF"
XML_FOLDER = "path/to/xml_folder"
GROBID_URL = "http://localhost:8070/api/processFulltextDocument"

# === Statistics ===
success_count = 0
fail_count = 0
skipped_count = 0

# === Ensure output folder exists ===
os.makedirs(XML_FOLDER, exist_ok=True)

# === Process each PDF file ===
for pdf_file in os.listdir(PDF_FOLDER):
    if not pdf_file.lower().endswith(".pdf"):
        continue

    pdf_path = os.path.join(PDF_FOLDER, pdf_file)
    xml_filename = os.path.splitext(pdf_file)[0] + ".xml"
    xml_path = os.path.join(XML_FOLDER, xml_filename)

    # Skip if XML already exists
    if os.path.exists(xml_path):
        print(f"Skipping {pdf_file} (already converted)")
        skipped_count += 1
        continue

    print(f"Converting {pdf_file}...")

    try:
        with open(pdf_path, "rb") as f:
            response = requests.post(
                GROBID_URL,
                files={"input": f},
                timeout=60
            )

        if response.status_code == 200:
            with open(xml_path, "w", encoding="utf-8") as out_file:
                out_file.write(response.text)
            print(f"✓ Success: {pdf_file}")
            success_count += 1
        else:
            print(f"✗ Failed (HTTP {response.status_code}): {pdf_file}")
            fail_count += 1

    except Exception as e:
        print(f"✗ Error processing {pdf_file}: {e}")
        fail_count += 1

# === Summary ===
print("\n=== Summary ===")
print(f"Total PDFs found: {len([f for f in os.listdir(PDF_FOLDER) if f.lower().endswith('.pdf')])}")
print(f"Converted: {success_count}")
print(f"Failed: {fail_count}")
print(f"Skipped (already exists): {skipped_count}")
# Out:
# Converting 10.1002_2017jc013030.pdf...
# ✓ Success: 10.1002_2017jc013030.pdf
# Converting 10.1002_anie.201916483.pdf...
# ✓ Success: 10.1002_anie.201916483.pdf
# Converting 10.1002_anie.202005531.pdf...
# ✓ Success: 10.1002_anie.202005531.pdf
# Converting 10.1002_anie.202007717.pdf...
# ✓ Success: 10.1002_anie.202007717.pdf
# Converting 10.1002_chem.201902131.pdf...
# ✓ Success: 10.1002_chem.201902131.pdf
# Converting 10.1002_chem.201903120.pdf...
# ✓ Success: 10.1002_chem.201903120.pdf
# Converting 10.1002_chem.202000235.pdf...
# ✓ Success: 10.1002_chem.202000235.pdf
# Converting 10.1002_chem.202001412.pdf...
# ✓ Success: 10.1002_chem.202001412.pdf
# Converting 10.1002_chem.202001668.pdf...
# ✓ Success: 10.1002_chem.202001668.pdf
# Converting 10.1002_chem.202003167.pdf...
# ✓ Success: 10.1002_chem.202003167.pdf
# Converting 10.1002_cssc.202201821.pdf...
# ✓ Success: 10.1002_cssc.202201821.pdf
# Converting 10.1002_ece3.3985.pdf...
# ✓ Success: 10.1002_ece3.3985.pdf
# Converting 10.1002_ece3.4466.pdf...
# ✓ Success: 10.1002_ece3.4466.pdf
# Converting 10.1002_ece3.5260.pdf...
# ✓ Success: 10.1002_ece3.5260.pdf
# Converting 10.1002_ece3.5395.pdf...
# ✓ Success: 10.1002_ece3.5395.pdf
# Converting 10.1002_ece3.6144.pdf...
# ✓ Success: 10.1002_ece3.6144.pdf
# Converting 10.1002_ece3.6303.pdf...
# ✓ Success: 10.1002_ece3.6303.pdf
# Converting 10.1002_ece3.6784.pdf...
# ✓ Success: 10.1002_ece3.6784.pdf
# Converting 10.1002_ece3.961.pdf...
# ✓ Success: 10.1002_ece3.961.pdf
# Converting 10.1002_ece3.9627.pdf...
# ✓ Success: 10.1002_ece3.9627.pdf
# Converting 10.1002_ecs2.1280.pdf...
# ✓ Success: 10.1002_ecs2.1280.pdf
# Converting 10.1002_ecs2.4619.pdf...
# ✓ Success: 10.1002_ecs2.4619.pdf
# Converting 10.1002_ejic.201900904.pdf...
# ✓ Success: 10.1002_ejic.201900904.pdf
# Converting 10.1002_ejoc.202000139.pdf...
# ✓ Success: 10.1002_ejoc.202000139.pdf
# Converting 10.1002_ejoc.202000916.pdf...
# ✓ Success: 10.1002_ejoc.202000916.pdf
# Converting 10.1002_esp.5058.pdf...
# ✓ Success: 10.1002_esp.5058.pdf
# Converting 10.1002_esp.5090.pdf...
# ✓ Success: 10.1002_esp.5090.pdf
# Converting 10.1002_mp.14424.pdf...
# ✓ Success: 10.1002_mp.14424.pdf
# Converting 10.1002_nafm.10870.pdf...
# ✓ Success: 10.1002_nafm.10870.pdf
# Converting 10.1007_jhep07(2018)134.pdf...
# ✓ Success: 10.1007_jhep07(2018)134.pdf
# Converting 10.1007_jhep11(2018)113.pdf...
# ✓ Success: 10.1007_jhep11(2018)113.pdf
# Converting 10.1007_jhep11(2018)115.pdf...
# ✓ Success: 10.1007_jhep11(2018)115.pdf
# Converting 10.1007_jhep12(2018)117.pdf...
# ✓ Success: 10.1007_jhep12(2018)117.pdf
# Converting 10.1007_s00259-022-06053-8.pdf...
# ✓ Success: 10.1007_s00259-022-06053-8.pdf
# Converting 10.1007_s00382-012-1636-1.pdf...
# ✓ Success: 10.1007_s00382-012-1636-1.pdf
# Converting 10.1007_s00382-022-06361-7.pdf...
# ✓ Success: 10.1007_s00382-022-06361-7.pdf
# Converting 10.1007_s00442-022-05201-z.pdf...
# ✓ Success: 10.1007_s00442-022-05201-z.pdf
# Converting 10.1007_s10904-014-0054-8.pdf...
# ✓ Success: 10.1007_s10904-014-0054-8.pdf
# Converting 10.1007_s12263-014-0408-4.pdf...
# ✓ Success: 10.1007_s12263-014-0408-4.pdf
# Converting 10.1007_s12559-020-09751-3.pdf...
# ✓ Success: 10.1007_s12559-020-09751-3.pdf
# Converting 10.1016_j.ast.2022.107401.pdf...
# ✓ Success: 10.1016_j.ast.2022.107401.pdf
# Converting 10.1016_j.cpc.2024.109087.pdf...
# ✓ Success: 10.1016_j.cpc.2024.109087.pdf
# Converting 10.1016_j.dib.2022.108797.pdf...
# ✓ Success: 10.1016_j.dib.2022.108797.pdf
# Converting 10.1016_j.dib.2023.109949.pdf...
# ✓ Success: 10.1016_j.dib.2023.109949.pdf
# Converting 10.1016_j.ecolind.2021.107934.pdf...
# ✓ Success: 10.1016_j.ecolind.2021.107934.pdf
# Converting 10.1016_j.fuel.2022.125768.pdf...
# ✓ Success: 10.1016_j.fuel.2022.125768.pdf
# Converting 10.1016_j.jlp.2022.104761.pdf...
# ✓ Success: 10.1016_j.jlp.2022.104761.pdf
# Converting 10.1016_j.jobe.2023.107105.pdf...
# ✓ Success: 10.1016_j.jobe.2023.107105.pdf
# Converting 10.1016_j.jsames.2022.103824.pdf...
# ✓ Success: 10.1016_j.jsames.2022.103824.pdf
# Converting 10.1016_j.molcel.2018.11.006.pdf...
# ✓ Success: 10.1016_j.molcel.2018.11.006.pdf
# Converting 10.1016_j.scitotenv.2024.171850.pdf...
# ✓ Success: 10.1016_j.scitotenv.2024.171850.pdf
# Converting 10.1016_j.websem.2024.100815.pdf...
# ✓ Success: 10.1016_j.websem.2024.100815.pdf
# Converting 10.1017_rdc.2022.19.pdf...
# ✓ Success: 10.1017_rdc.2022.19.pdf
# Converting 10.1017_s0007123423000601.pdf...
# ✓ Success: 10.1017_s0007123423000601.pdf
# Converting 10.1021_acs.jcim.9b01185.pdf...
# ✓ Success: 10.1021_acs.jcim.9b01185.pdf
# Converting 10.1021_acscentsci.1c01109.pdf...
# ✓ Success: 10.1021_acscentsci.1c01109.pdf
# Converting 10.1021_acsomega.3c06074.pdf...
# ✓ Success: 10.1021_acsomega.3c06074.pdf
# Converting 10.1021_jacs.2c06519.pdf...
# ✓ Success: 10.1021_jacs.2c06519.pdf
# Converting 10.1029_2018gl078007.pdf...
# ✓ Success: 10.1029_2018gl078007.pdf
# Converting 10.1029_2019jg005297.pdf...
# ✓ Success: 10.1029_2019jg005297.pdf
# Converting 10.1029_2019pa003774.pdf...
# ✓ Success: 10.1029_2019pa003774.pdf
# Converting 10.1029_2020jf005675.pdf...
# ✓ Success: 10.1029_2020jf005675.pdf
# Converting 10.1029_2021ea001703.pdf...
# ✓ Success: 10.1029_2021ea001703.pdf
# Converting 10.1029_2021gl096173.pdf...
# ✓ Success: 10.1029_2021gl096173.pdf
# Converting 10.1029_2021pa004379.pdf...
# ✓ Success: 10.1029_2021pa004379.pdf
# Converting 10.1029_2022gl100473.pdf...
# ✓ Success: 10.1029_2022gl100473.pdf
# Converting 10.1029_2023ea002840.pdf...
# ✓ Success: 10.1029_2023ea002840.pdf
# Converting 10.1029_2023wr035126.pdf...
# ✓ Success: 10.1029_2023wr035126.pdf
# Converting 10.1038_hdy.2013.74.pdf...
# ✓ Success: 10.1038_hdy.2013.74.pdf
# Converting 10.1038_hdy.2014.75.pdf...
# ✓ Success: 10.1038_hdy.2014.75.pdf
# Converting 10.1038_hdy.2015.99.pdf...
# ✓ Success: 10.1038_hdy.2015.99.pdf
# Converting 10.1038_ncomms11871.pdf...
# ✓ Success: 10.1038_ncomms11871.pdf
# Converting 10.1038_s41396-020-00885-8.pdf...
# ✓ Success: 10.1038_s41396-020-00885-8.pdf
# Converting 10.1038_s41437-020-0318-8.pdf...
# ✓ Success: 10.1038_s41437-020-0318-8.pdf
# Converting 10.1038_s41467-018-04041-x.pdf...
# ✓ Success: 10.1038_s41467-018-04041-x.pdf
# Converting 10.1038_s41467-018-07681-1.pdf...
# ✓ Success: 10.1038_s41467-018-07681-1.pdf
# Converting 10.1038_s41467-019-10357-z.pdf...
# ✓ Success: 10.1038_s41467-019-10357-z.pdf
# Converting 10.1038_s41558-022-01301-z.pdf...
# ✓ Success: 10.1038_s41558-022-01301-z.pdf
# Converting 10.1038_s41562-021-01247-w.pdf...
# ✓ Success: 10.1038_s41562-021-01247-w.pdf
# Converting 10.1038_s41597-019-0101-y.pdf...
# ✓ Success: 10.1038_s41597-019-0101-y.pdf
# Converting 10.1038_s41597-022-01555-4.pdf...
# ✓ Success: 10.1038_s41597-022-01555-4.pdf
# Converting 10.1038_s41597-023-02280-2.pdf...
# ✓ Success: 10.1038_s41597-023-02280-2.pdf
# Converting 10.1038_s41598-017-15852-1.pdf...
# ✓ Success: 10.1038_s41598-017-15852-1.pdf
# Converting 10.1038_s41598-020-59839-x.pdf...
# ✓ Success: 10.1038_s41598-020-59839-x.pdf
# Converting 10.1038_s41598-021-85671-y.pdf...
# ✓ Success: 10.1038_s41598-021-85671-y.pdf
# Converting 10.1038_s41598-024-56373-y.pdf...
# ✓ Success: 10.1038_s41598-024-56373-y.pdf
# Converting 10.1038_s41893-020-0559-9.pdf...
# ✓ Success: 10.1038_s41893-020-0559-9.pdf
# Converting 10.1038_sdata.2017.167.pdf...
# ✓ Success: 10.1038_sdata.2017.167.pdf
# Converting 10.1039_c5sc01309g.pdf...
# ✓ Success: 10.1039_c5sc01309g.pdf
# Converting 10.1039_c9ce01020c.pdf...
# ✓ Success: 10.1039_c9ce01020c.pdf
# Converting 10.1039_c9ra06638a.pdf...
# ✓ Success: 10.1039_c9ra06638a.pdf
# Converting 10.1039_c9sc02930c.pdf...
# ✓ Success: 10.1039_c9sc02930c.pdf
# Converting 10.1039_d0dt02130j.pdf...
# ✓ Success: 10.1039_d0dt02130j.pdf
# Converting 10.1039_d0gc00363h.pdf...
# ✓ Success: 10.1039_d0gc00363h.pdf
# Converting 10.1039_d0sc01197e.pdf...
# ✓ Success: 10.1039_d0sc01197e.pdf
# Converting 10.1039_d0sc01518k.pdf...
# ✓ Success: 10.1039_d0sc01518k.pdf
# Converting 10.1039_d0sc02283g.pdf...
# ✓ Success: 10.1039_d0sc02283g.pdf
# Converting 10.1039_d0sc02676j.pdf...
# ✓ Success: 10.1039_d0sc02676j.pdf
# Converting 10.1039_d0sc03604h.pdf...
# ✓ Success: 10.1039_d0sc03604h.pdf
# Converting 10.1039_d1ee03696c.pdf...
# ✓ Success: 10.1039_d1ee03696c.pdf
# Converting 10.1039_d2cc00847e.pdf...
# ✓ Success: 10.1039_d2cc00847e.pdf
# Converting 10.1051_e3sconf_202017220004.pdf...
# ✓ Success: 10.1051_e3sconf_202017220004.pdf
# Converting 10.1055_s-0039-1693681.pdf...
# ✓ Success: 10.1055_s-0039-1693681.pdf
# Converting 10.1073_pnas.1323607111.pdf...
# ✓ Success: 10.1073_pnas.1323607111.pdf
# Converting 10.1073_pnas.1705601114.pdf...
# ✓ Success: 10.1073_pnas.1705601114.pdf
# Converting 10.1073_pnas.1711872115.pdf...
# ✓ Success: 10.1073_pnas.1711872115.pdf
# Converting 10.1073_pnas.1915395117.pdf...
# ✓ Success: 10.1073_pnas.1915395117.pdf
# Converting 10.1073_pnas.2306723120.pdf...
# ✓ Success: 10.1073_pnas.2306723120.pdf
# Converting 10.1080_01621459.2019.1573732.pdf...
# ✓ Success: 10.1080_01621459.2019.1573732.pdf
# Converting 10.1080_02713683.2019.1607392.pdf...
# ✓ Success: 10.1080_02713683.2019.1607392.pdf
# Converting 10.1080_0284186x.2019.1669817.pdf...
# ✓ Success: 10.1080_0284186x.2019.1669817.pdf
# Converting 10.1080_0284186x.2020.1714721.pdf...
# ✓ Success: 10.1080_0284186x.2020.1714721.pdf
# Converting 10.1080_07350015.2020.1766469.pdf...
# ✓ Success: 10.1080_07350015.2020.1766469.pdf
# Converting 10.1080_13501763.2019.1630470.pdf...
# ✓ Success: 10.1080_13501763.2019.1630470.pdf
# Converting 10.1080_14756366.2020.1740692.pdf...
# ✓ Success: 10.1080_14756366.2020.1740692.pdf
# Converting 10.1080_15476286.2016.1232238.pdf...
# ✓ Success: 10.1080_15476286.2016.1232238.pdf
# Converting 10.1080_19475683.2023.2226196.pdf...
# ✓ Success: 10.1080_19475683.2023.2226196.pdf
# Converting 10.1080_21645515.2023.2189598.pdf...
# ✓ Success: 10.1080_21645515.2023.2189598.pdf
# Converting 10.1080_22221751.2020.1738277.pdf...
# ✓ Success: 10.1080_22221751.2020.1738277.pdf
# Converting 10.1093_beheco_arad016.pdf...
# ✓ Success: 10.1093_beheco_arad016.pdf
# Converting 10.1093_beheco_arw167.pdf...
# ✓ Success: 10.1093_beheco_arw167.pdf
# Converting 10.1093_beheco_arz101.pdf...
# ✓ Success: 10.1093_beheco_arz101.pdf
# Converting 10.1093_bib_bbab395.pdf...
# ✓ Success: 10.1093_bib_bbab395.pdf
# Converting 10.1093_evolut_qpad206.pdf...
# ✓ Success: 10.1093_evolut_qpad206.pdf
# Converting 10.1093_nar_gkp1049.pdf...
# ✓ Success: 10.1093_nar_gkp1049.pdf
# Converting 10.1093_sysbio_syy011.pdf...
# ✓ Success: 10.1093_sysbio_syy011.pdf
# Converting 10.1098_rsbl.2015.0113.pdf...
# ✓ Success: 10.1098_rsbl.2015.0113.pdf
# Converting 10.1098_rsos.160417.pdf...
# ✓ Success: 10.1098_rsos.160417.pdf
# Converting 10.1098_rsos.170796.pdf...
# ✓ Success: 10.1098_rsos.170796.pdf
# Converting 10.1098_rsos.190841.pdf...
# ✓ Success: 10.1098_rsos.190841.pdf
# Converting 10.1098_rsos.210982.pdf...
# ✓ Success: 10.1098_rsos.210982.pdf
# Converting 10.1098_rspb.2015.0371.pdf...
# ✓ Success: 10.1098_rspb.2015.0371.pdf
# Converting 10.1098_rspb.2015.1498.pdf...
# ✓ Success: 10.1098_rspb.2015.1498.pdf
# Converting 10.1098_rspb.2015.2726.pdf...
# ✓ Success: 10.1098_rspb.2015.2726.pdf
# Converting 10.1098_rspb.2015.2764.pdf...
# ✓ Success: 10.1098_rspb.2015.2764.pdf
# Converting 10.1101_096297.pdf...
# ✓ Success: 10.1101_096297.pdf
# Converting 10.1101_2022.02.10.480011.pdf...
# ✓ Success: 10.1101_2022.02.10.480011.pdf
# Converting 10.1101_2022.07.21.501061.pdf...
# ✓ Success: 10.1101_2022.07.21.501061.pdf
# Converting 10.1103_physrevresearch.4.023008.pdf...
# ✓ Success: 10.1103_physrevresearch.4.023008.pdf
# Converting 10.1107_s0108270106019688.pdf...
# ✓ Success: 10.1107_s0108270106019688.pdf
# Converting 10.1107_s1600536807066780.pdf...
# ✓ Success: 10.1107_s1600536807066780.pdf
# Converting 10.1107_s1600536808011148.pdf...
# ✓ Success: 10.1107_s1600536808011148.pdf
# Converting 10.1107_s1600536809014883.pdf...
# ✓ Success: 10.1107_s1600536809014883.pdf
# Converting 10.1107_s1600536809022582.pdf...
# ✗ Failed (HTTP 500): 10.1107_s1600536809022582.pdf
# Converting 10.1107_s1600536809043700.pdf...
# ✓ Success: 10.1107_s1600536809043700.pdf
# Converting 10.1107_s1600536810036299.pdf...
# ✓ Success: 10.1107_s1600536810036299.pdf
# Converting 10.1107_s1600536810047185.pdf...
# ✗ Failed (HTTP 500): 10.1107_s1600536810047185.pdf
# Converting 10.1107_s1600536811003163.pdf...
# ✗ Failed (HTTP 500): 10.1107_s1600536811003163.pdf
# Converting 10.1107_s160053681102201x.pdf...
# ✗ Failed (HTTP 500): 10.1107_s160053681102201x.pdf
# Converting 10.1107_s160053681103220x.pdf...
# ✓ Success: 10.1107_s160053681103220x.pdf
# Converting 10.1107_s1600536811042164.pdf...
# ✗ Failed (HTTP 500): 10.1107_s1600536811042164.pdf
# Converting 10.1107_s1600536812014614.pdf...
# ✗ Failed (HTTP 500): 10.1107_s1600536812014614.pdf
# Converting 10.1107_s1600536812019885.pdf...
# ✗ Failed (HTTP 500): 10.1107_s1600536812019885.pdf
# Converting 10.1107_s1600536812024269.pdf...
# ✓ Success: 10.1107_s1600536812024269.pdf
# Converting 10.1107_s1600536812027390.pdf...
# ✗ Failed (HTTP 500): 10.1107_s1600536812027390.pdf
# Converting 10.1107_s1600536812046892.pdf...
# ✗ Failed (HTTP 500): 10.1107_s1600536812046892.pdf
# Converting 10.1107_s2052252514012081.pdf...
# ✓ Success: 10.1107_s2052252514012081.pdf
# Converting 10.1107_s2052252515010271.pdf...
# ✓ Success: 10.1107_s2052252515010271.pdf
# Converting 10.1107_s2052252515011665.pdf...
# ✓ Success: 10.1107_s2052252515011665.pdf
# Converting 10.1107_s2052252515023945.pdf...
# ✓ Success: 10.1107_s2052252515023945.pdf
# Converting 10.1107_s2052252520013603.pdf...
# ✓ Success: 10.1107_s2052252520013603.pdf
# Converting 10.1107_s2053229620003757.pdf...
# ✓ Success: 10.1107_s2053229620003757.pdf
# Converting 10.1107_s2056989014026358.pdf...
# ✗ Failed (HTTP 500): 10.1107_s2056989014026358.pdf
# Converting 10.1107_s2056989015010257.pdf...
# ✗ Failed (HTTP 500): 10.1107_s2056989015010257.pdf
# Converting 10.1107_s2056989015019891.pdf...
# ✓ Success: 10.1107_s2056989015019891.pdf
# Converting 10.1107_s2056989016016819.pdf...
# ✓ Success: 10.1107_s2056989016016819.pdf
# Converting 10.1107_s2056989020010658.pdf...
# ✓ Success: 10.1107_s2056989020010658.pdf
# Converting 10.1107_s2059798322005691.pdf...
# ✓ Success: 10.1107_s2059798322005691.pdf
# Converting 10.1107_s2414314616000523.pdf...
# ✓ Success: 10.1107_s2414314616000523.pdf
# Converting 10.1107_s2414314616007033.pdf...
# ✓ Success: 10.1107_s2414314616007033.pdf
# Converting 10.1107_s2414314616007227.pdf...
# ✓ Success: 10.1107_s2414314616007227.pdf
# Converting 10.1107_s2414314619012446.pdf...
# ✓ Success: 10.1107_s2414314619012446.pdf
# Converting 10.1109_access.2024.3385658.pdf...
# ✓ Success: 10.1109_access.2024.3385658.pdf
# Converting 10.1111_1365-2435.13087.pdf...
# ✓ Success: 10.1111_1365-2435.13087.pdf
# Converting 10.1111_1365-2435.13431.pdf...
# ✓ Success: 10.1111_1365-2435.13431.pdf
# Converting 10.1111_1365-2435.13569.pdf...
# ✓ Success: 10.1111_1365-2435.13569.pdf
# Converting 10.1111_1365-2656.12382.pdf...
# ✓ Success: 10.1111_1365-2656.12382.pdf
# Converting 10.1111_1365-2656.12491.pdf...
# ✓ Success: 10.1111_1365-2656.12491.pdf
# Converting 10.1111_1365-2656.12501.pdf...
# ✓ Success: 10.1111_1365-2656.12501.pdf
# Converting 10.1111_1365-2656.12594.pdf...
# ✓ Success: 10.1111_1365-2656.12594.pdf
# Converting 10.1111_1365-2664.13128.pdf...
# ✓ Success: 10.1111_1365-2664.13128.pdf
# Converting 10.1111_1365-2664.13136.pdf...
# ✓ Success: 10.1111_1365-2664.13136.pdf
# Converting 10.1111_1365-2664.13168.pdf...
# ✓ Success: 10.1111_1365-2664.13168.pdf
# Converting 10.1111_1365-2664.13446.pdf...
# ✓ Success: 10.1111_1365-2664.13446.pdf
# Converting 10.1111_1365-2745.13449.pdf...
# ✓ Success: 10.1111_1365-2745.13449.pdf
# Converting 10.1111_2041-210x.12453.pdf...
# ✓ Success: 10.1111_2041-210x.12453.pdf
# Converting 10.1111_2041-210x.13817.pdf...
# ✓ Success: 10.1111_2041-210x.13817.pdf
# Converting 10.1111_acel.13089.pdf...
# ✓ Success: 10.1111_acel.13089.pdf
# Converting 10.1111_bph.14747.pdf...
# ✓ Success: 10.1111_bph.14747.pdf
# Converting 10.1111_cas.12935.pdf...
# ✓ Success: 10.1111_cas.12935.pdf
# Converting 10.1111_ddi.13153.pdf...
# ✓ Success: 10.1111_ddi.13153.pdf
# Converting 10.1111_ddi.13161.pdf...
# ✓ Success: 10.1111_ddi.13161.pdf
# Converting 10.1111_ejn.13855.pdf...
# ✓ Success: 10.1111_ejn.13855.pdf
# Converting 10.1111_eva.12151.pdf...
# ✓ Success: 10.1111_eva.12151.pdf
# Converting 10.1111_eva.12446.pdf...
# ✓ Success: 10.1111_eva.12446.pdf
# Converting 10.1111_eva.12768.pdf...
# ✓ Success: 10.1111_eva.12768.pdf
# Converting 10.1111_evo.13972.pdf...
# ✓ Success: 10.1111_evo.13972.pdf
# Converting 10.1111_gcb.13914.pdf...
# ✓ Success: 10.1111_gcb.13914.pdf
# Converting 10.1111_gcb.14974.pdf...
# ✓ Success: 10.1111_gcb.14974.pdf
# Converting 10.1111_ggr.12517.pdf...
# ✓ Success: 10.1111_ggr.12517.pdf
# Converting 10.1111_mec.16743.pdf...
# ✓ Success: 10.1111_mec.16743.pdf
# Converting 10.1111_mec.16977.pdf...
# ✓ Success: 10.1111_mec.16977.pdf
# Converting 10.1111_njb.02077.pdf...
# ✓ Success: 10.1111_njb.02077.pdf
# Converting 10.1128_JVI.01717-21.pdf...
# ✓ Success: 10.1128_JVI.01717-21.pdf
# Converting 10.1128_spectrum.00422-24.pdf...
# ✓ Success: 10.1128_spectrum.00422-24.pdf
# Converting 10.1130_ges01387.1.pdf...
# ✓ Success: 10.1130_ges01387.1.pdf
# Converting 10.1136_jitc-2021-003114.pdf...
# ✓ Success: 10.1136_jitc-2021-003114.pdf
# Converting 10.1140_epjc_s10052-016-4366-4.pdf...
# ✓ Success: 10.1140_epjc_s10052-016-4366-4.pdf
# Converting 10.1140_epjc_s10052-018-6033-4.pdf...
# ✓ Success: 10.1140_epjc_s10052-018-6033-4.pdf
# Converting 10.1140_epjc_s10052-018-6468-7.pdf...
# ✓ Success: 10.1140_epjc_s10052-018-6468-7.pdf
# Converting 10.1140_epjc_s10052-019-6583-0.pdf...
# ✓ Success: 10.1140_epjc_s10052-019-6583-0.pdf
# Converting 10.1140_epjds_s13688-018-0132-1.pdf...
# ✓ Success: 10.1140_epjds_s13688-018-0132-1.pdf
# Converting 10.1145_3461702.3462538.pdf...
# ✓ Success: 10.1145_3461702.3462538.pdf
# Converting 10.1155_2013_536562.pdf...
# ✓ Success: 10.1155_2013_536562.pdf
# Converting 10.1177_0018720820970751.pdf...
# ✓ Success: 10.1177_0018720820970751.pdf
# Converting 10.1186_1471-244x-13-259.pdf...
# ✓ Success: 10.1186_1471-244x-13-259.pdf
# Converting 10.1186_1752-153x-7-123.pdf...
# ✓ Success: 10.1186_1752-153x-7-123.pdf
# Converting 10.1186_gb-2010-11-10-r101.pdf...
# ✓ Success: 10.1186_gb-2010-11-10-r101.pdf
# Converting 10.1186_s11658-018-0120-2.pdf...
# ✓ Success: 10.1186_s11658-018-0120-2.pdf
# Converting 10.1186_s11689-019-9287-8.pdf...
# ✓ Success: 10.1186_s11689-019-9287-8.pdf
# Converting 10.1186_s12859-016-0904-1.pdf...
# ✓ Success: 10.1186_s12859-016-0904-1.pdf
# Converting 10.1186_s12859-016-0922-z.pdf...
# ✓ Success: 10.1186_s12859-016-0922-z.pdf
# Converting 10.1186_s12859-016-0938-4.pdf...
# ✓ Success: 10.1186_s12859-016-0938-4.pdf
# Converting 10.1186_s12859-016-1206-3.pdf...
# ✓ Success: 10.1186_s12859-016-1206-3.pdf
# Converting 10.1186_s12859-017-1563-6.pdf...
# ✓ Success: 10.1186_s12859-017-1563-6.pdf
# Converting 10.1186_s12859-017-1952-x.pdf...
# ✓ Success: 10.1186_s12859-017-1952-x.pdf
# Converting 10.1186_s12859-018-2036-2.pdf...
# ✓ Success: 10.1186_s12859-018-2036-2.pdf
# Converting 10.1186_s12859-018-2146-x.pdf...
# ✓ Success: 10.1186_s12859-018-2146-x.pdf
# Converting 10.1186_s12859-018-2263-6.pdf...
# ✓ Success: 10.1186_s12859-018-2263-6.pdf
# Converting 10.1186_s12859-018-2414-9.pdf...
# ✓ Success: 10.1186_s12859-018-2414-9.pdf
# Converting 10.1186_s12859-020-3415-z.pdf...
# ✓ Success: 10.1186_s12859-020-3415-z.pdf
# Converting 10.1186_s12859-020-3496-8.pdf...
# ✓ Success: 10.1186_s12859-020-3496-8.pdf
# Converting 10.1186_s12860-020-00261-6.pdf...
# ✓ Success: 10.1186_s12860-020-00261-6.pdf
# Converting 10.1186_s12862-015-0558-z.pdf...
# ✓ Success: 10.1186_s12862-015-0558-z.pdf
# Converting 10.1186_s12862-018-1213-2.pdf...
# ✓ Success: 10.1186_s12862-018-1213-2.pdf
# Converting 10.1186_s12862-019-1388-1.pdf...
# ✓ Success: 10.1186_s12862-019-1388-1.pdf
# Converting 10.1186_s12862-019-1509-x.pdf...
# ✓ Success: 10.1186_s12862-019-1509-x.pdf
# Converting 10.1186_s12863-017-0513-7.pdf...
# ✓ Success: 10.1186_s12863-017-0513-7.pdf
# Converting 10.1186_s12863-019-0790-4.pdf...
# ✓ Success: 10.1186_s12863-019-0790-4.pdf
# Converting 10.1186_s12864-015-2206-9.pdf...
# ✓ Success: 10.1186_s12864-015-2206-9.pdf
# Converting 10.1186_s12864-018-4947-8.pdf...
# ✓ Success: 10.1186_s12864-018-4947-8.pdf
# Converting 10.1186_s12864-018-5054-6.pdf...
# ✓ Success: 10.1186_s12864-018-5054-6.pdf
# Converting 10.1186_s12864-018-5198-4.pdf...
# ✓ Success: 10.1186_s12864-018-5198-4.pdf
# Converting 10.1186_s12864-019-5872-1.pdf...
# ✓ Success: 10.1186_s12864-019-5872-1.pdf
# Converting 10.1186_s12864-019-6099-x.pdf...
# ✓ Success: 10.1186_s12864-019-6099-x.pdf
# Converting 10.1186_s12864-019-6131-1.pdf...
# ✓ Success: 10.1186_s12864-019-6131-1.pdf
# Converting 10.1186_s12864-019-6324-7.pdf...
# ✓ Success: 10.1186_s12864-019-6324-7.pdf
# Converting 10.1186_s12864-020-6657-2.pdf...
# ✓ Success: 10.1186_s12864-020-6657-2.pdf
# Converting 10.1186_s12866-015-0509-2.pdf...
# ✓ Success: 10.1186_s12866-015-0509-2.pdf
# Converting 10.1186_s12866-019-1542-3.pdf...
# ✓ Success: 10.1186_s12866-019-1542-3.pdf
# Converting 10.1186_s12866-020-01863-y.pdf...
# ✓ Success: 10.1186_s12866-020-01863-y.pdf
# Converting 10.1186_s12868-018-0468-2.pdf...
# ✓ Success: 10.1186_s12868-018-0468-2.pdf
# Converting 10.1186_s12868-019-0514-8.pdf...
# ✓ Success: 10.1186_s12868-019-0514-8.pdf
# Converting 10.1186_s12870-018-1332-3.pdf...
# ✓ Success: 10.1186_s12870-018-1332-3.pdf
# Converting 10.1186_s12870-018-1542-8.pdf...
# ✓ Success: 10.1186_s12870-018-1542-8.pdf
# Converting 10.1186_s12870-019-1632-2.pdf...
# ✓ Success: 10.1186_s12870-019-1632-2.pdf
# Converting 10.1186_s12870-019-1889-5.pdf...
# ✓ Success: 10.1186_s12870-019-1889-5.pdf
# Converting 10.1186_s12870-019-1904-x.pdf...
# ✓ Success: 10.1186_s12870-019-1904-x.pdf
# Converting 10.1186_s12870-019-1926-4.pdf...
# ✓ Success: 10.1186_s12870-019-1926-4.pdf
# Converting 10.1186_s12870-019-2199-7.pdf...
# ✓ Success: 10.1186_s12870-019-2199-7.pdf
# Converting 10.1186_s12870-020-02651-6.pdf...
# ✓ Success: 10.1186_s12870-020-02651-6.pdf
# Converting 10.1186_s12870-020-02692-x.pdf...
# ✓ Success: 10.1186_s12870-020-02692-x.pdf
# Converting 10.1186_s12870-020-2295-8.pdf...
# ✓ Success: 10.1186_s12870-020-2295-8.pdf
# Converting 10.1186_s12874-018-0583-x.pdf...
# ✓ Success: 10.1186_s12874-018-0583-x.pdf
# Converting 10.1186_s12874-019-0829-2.pdf...
# ✓ Success: 10.1186_s12874-019-0829-2.pdf
# Converting 10.1186_s12879-018-3065-1.pdf...
# ✓ Success: 10.1186_s12879-018-3065-1.pdf
# Converting 10.1186_s12879-019-3766-0.pdf...
# ✓ Success: 10.1186_s12879-019-3766-0.pdf
# Converting 10.1186_s12881-019-0773-3.pdf...
# ✓ Success: 10.1186_s12881-019-0773-3.pdf
# Converting 10.1186_s12882-019-1494-8.pdf...
# ✓ Success: 10.1186_s12882-019-1494-8.pdf
# Converting 10.1186_s12884-018-1751-z.pdf...
# ✓ Success: 10.1186_s12884-018-1751-z.pdf
# Converting 10.1186_s12885-017-3237-1.pdf...
# ✓ Success: 10.1186_s12885-017-3237-1.pdf
# Converting 10.1186_s12885-018-4229-5.pdf...
# ✓ Success: 10.1186_s12885-018-4229-5.pdf
# Converting 10.1186_s12885-018-4314-9.pdf...
# ✓ Success: 10.1186_s12885-018-4314-9.pdf
# Converting 10.1186_s12885-018-4768-9.pdf...
# ✓ Success: 10.1186_s12885-018-4768-9.pdf
# Converting 10.1186_s12885-019-5681-6.pdf...
# ✓ Success: 10.1186_s12885-019-5681-6.pdf
# Converting 10.1186_s12885-020-06724-5.pdf...
# ✓ Success: 10.1186_s12885-020-06724-5.pdf
# Converting 10.1186_s12903-018-0656-6.pdf...
# ✓ Success: 10.1186_s12903-018-0656-6.pdf
# Converting 10.1186_s12906-019-2769-0.pdf...
# ✓ Success: 10.1186_s12906-019-2769-0.pdf
# Converting 10.1186_s12913-018-3333-1.pdf...
# ✓ Success: 10.1186_s12913-018-3333-1.pdf
# Converting 10.1186_s12915-018-0498-3.pdf...
# ✓ Success: 10.1186_s12915-018-0498-3.pdf
# Converting 10.1186_s12915-018-0584-6.pdf...
# ✓ Success: 10.1186_s12915-018-0584-6.pdf
# Converting 10.1186_s12916-019-1469-4.pdf...
# ✓ Success: 10.1186_s12916-019-1469-4.pdf
# Converting 10.1186_s12918-015-0209-4.pdf...
# ✓ Success: 10.1186_s12918-015-0209-4.pdf
# Converting 10.1186_s12918-018-0564-z.pdf...
# ✓ Success: 10.1186_s12918-018-0564-z.pdf
# Converting 10.1186_s12918-018-0620-8.pdf...
# ✓ Success: 10.1186_s12918-018-0620-8.pdf
# Converting 10.1186_s12920-018-0379-1.pdf...
# ✓ Success: 10.1186_s12920-018-0379-1.pdf
# Converting 10.1186_s12920-018-0403-5.pdf...
# ✓ Success: 10.1186_s12920-018-0403-5.pdf
# Converting 10.1186_s12920-018-0426-y.pdf...
# ✓ Success: 10.1186_s12920-018-0426-y.pdf
# Converting 10.1186_s12920-019-0611-7.pdf...
# ✓ Success: 10.1186_s12920-019-0611-7.pdf
# Converting 10.1186_s12920-019-0628-y.pdf...
# ✓ Success: 10.1186_s12920-019-0628-y.pdf
# Converting 10.1186_s12920-019-0646-9.pdf...
# ✓ Success: 10.1186_s12920-019-0646-9.pdf
# Converting 10.1186_s12920-020-00737-6.pdf...
# ✓ Success: 10.1186_s12920-020-00737-6.pdf
# Converting 10.1186_s12931-019-1001-6.pdf...
# ✓ Success: 10.1186_s12931-019-1001-6.pdf
# Converting 10.1186_s12933-019-0813-5.pdf...
# ✓ Success: 10.1186_s12933-019-0813-5.pdf
# Converting 10.1186_s12934-018-1005-9.pdf...
# ✓ Success: 10.1186_s12934-018-1005-9.pdf
# Converting 10.1186_s12935-020-01373-x.pdf...
# ✓ Success: 10.1186_s12935-020-01373-x.pdf
# Converting 10.1186_s12943-018-0878-x.pdf...
# ✓ Success: 10.1186_s12943-018-0878-x.pdf
# Converting 10.1186_s12943-019-1017-z.pdf...
# ✓ Success: 10.1186_s12943-019-1017-z.pdf
# Converting 10.1186_s12967-019-2100-3.pdf...
# ✓ Success: 10.1186_s12967-019-2100-3.pdf
# Converting 10.1186_s12967-020-02311-1.pdf...
# ✓ Success: 10.1186_s12967-020-02311-1.pdf
# Converting 10.1186_s12974-020-01860-y.pdf...
# ✓ Success: 10.1186_s12974-020-01860-y.pdf
# Converting 10.1186_s12977-015-0204-2.pdf...
# ✓ Success: 10.1186_s12977-015-0204-2.pdf
# Converting 10.1186_s13007-019-0403-2.pdf...
# ✓ Success: 10.1186_s13007-019-0403-2.pdf
# Converting 10.1186_s13014-018-1166-z.pdf...
# ✓ Success: 10.1186_s13014-018-1166-z.pdf
# Converting 10.1186_s13020-020-00307-z.pdf...
# ✓ Success: 10.1186_s13020-020-00307-z.pdf
# Converting 10.1186_s13024-018-0254-8.pdf...
# ✓ Success: 10.1186_s13024-018-0254-8.pdf
# Converting 10.1186_s13024-018-0266-4.pdf...
# ✓ Success: 10.1186_s13024-018-0266-4.pdf
# Converting 10.1186_s13039-022-00631-z.pdf...
# ✓ Success: 10.1186_s13039-022-00631-z.pdf
# Converting 10.1186_s13046-018-0843-y.pdf...
# ✓ Success: 10.1186_s13046-018-0843-y.pdf
# Converting 10.1186_s13054-015-0738-7.pdf...
# ✓ Success: 10.1186_s13054-015-0738-7.pdf
# Converting 10.1186_s13054-015-1052-0.pdf...
# ✓ Success: 10.1186_s13054-015-1052-0.pdf
# Converting 10.1186_s13054-019-2488-4.pdf...
# ✓ Success: 10.1186_s13054-019-2488-4.pdf
# Converting 10.1186_s13058-015-0618-8.pdf...
# ✓ Success: 10.1186_s13058-015-0618-8.pdf
# Converting 10.1186_s13059-017-1200-8.pdf...
# ✓ Success: 10.1186_s13059-017-1200-8.pdf
# Converting 10.1186_s13059-018-1557-3.pdf...
# ✓ Success: 10.1186_s13059-018-1557-3.pdf
# Converting 10.1186_s13059-019-1749-5.pdf...
# ✓ Success: 10.1186_s13059-019-1749-5.pdf
# Converting 10.1186_s13059-019-1840-y.pdf...
# ✓ Success: 10.1186_s13059-019-1840-y.pdf
# Converting 10.1186_s13059-019-1908-8.pdf...
# ✓ Success: 10.1186_s13059-019-1908-8.pdf
# Converting 10.1186_s13059-019-1918-6.pdf...
# ✓ Success: 10.1186_s13059-019-1918-6.pdf
# Converting 10.1186_s13059-019-1924-8.pdf...
# ✓ Success: 10.1186_s13059-019-1924-8.pdf
# Converting 10.1186_s13059-020-02048-6.pdf...
# ✓ Success: 10.1186_s13059-020-02048-6.pdf
# Converting 10.1186_s13059-020-1949-z.pdf...
# ✓ Success: 10.1186_s13059-020-1949-z.pdf
# Converting 10.1186_s13068-017-0901-2.pdf...
# ✓ Success: 10.1186_s13068-017-0901-2.pdf
# Converting 10.1186_s13068-018-1078-z.pdf...
# ✓ Success: 10.1186_s13068-018-1078-z.pdf
# Converting 10.1186_s13068-018-1167-z.pdf...
# ✓ Success: 10.1186_s13068-018-1167-z.pdf
# Converting 10.1186_s13068-018-1316-4.pdf...
# ✓ Success: 10.1186_s13068-018-1316-4.pdf
# Converting 10.1186_s13071-016-1359-y.pdf...
# ✓ Success: 10.1186_s13071-016-1359-y.pdf
# Converting 10.1186_s13071-018-2842-4.pdf...
# ✓ Success: 10.1186_s13071-018-2842-4.pdf
# Converting 10.1186_s13071-018-2964-8.pdf...
# ✓ Success: 10.1186_s13071-018-2964-8.pdf
# Converting 10.1186_s13071-018-3084-1.pdf...
# ✓ Success: 10.1186_s13071-018-3084-1.pdf
# Converting 10.1186_s13071-018-3237-2.pdf...
# ✓ Success: 10.1186_s13071-018-3237-2.pdf
# Converting 10.1186_s13072-019-0285-6.pdf...
# ✓ Success: 10.1186_s13072-019-0285-6.pdf
# Converting 10.1186_s13072-019-0322-5.pdf...
# ✓ Success: 10.1186_s13072-019-0322-5.pdf
# Converting 10.1186_s13073-019-0674-2.pdf...
# ✓ Success: 10.1186_s13073-019-0674-2.pdf
# Converting 10.1186_s13073-019-0709-8.pdf...
# ✓ Success: 10.1186_s13073-019-0709-8.pdf
# Converting 10.1186_s13073-020-00727-4.pdf...
# ✓ Success: 10.1186_s13073-020-00727-4.pdf
# Converting 10.1186_s13100-019-0153-8.pdf...
# ✓ Success: 10.1186_s13100-019-0153-8.pdf
# Converting 10.1186_s13104-018-4014-1.pdf...
# ✓ Success: 10.1186_s13104-018-4014-1.pdf
# Converting 10.1186_s13104-019-4058-x.pdf...
# ✓ Success: 10.1186_s13104-019-4058-x.pdf
# Converting 10.1186_s13104-019-4127-1.pdf...
# ✓ Success: 10.1186_s13104-019-4127-1.pdf
# Converting 10.1186_s13148-018-0581-1.pdf...
# ✓ Success: 10.1186_s13148-018-0581-1.pdf
# Converting 10.1186_s13148-019-0719-9.pdf...
# ✓ Success: 10.1186_s13148-019-0719-9.pdf
# Converting 10.1186_s13321-015-0110-6.pdf...
# ✓ Success: 10.1186_s13321-015-0110-6.pdf
# Converting 10.1186_s13321-017-0223-1.pdf...
# ✓ Success: 10.1186_s13321-017-0223-1.pdf
# Converting 10.1186_s13321-017-0246-7.pdf...
# ✓ Success: 10.1186_s13321-017-0246-7.pdf
# Converting 10.1186_s13321-018-0298-3.pdf...
# ✓ Success: 10.1186_s13321-018-0298-3.pdf
# Converting 10.1186_s13326-019-0195-3.pdf...
# ✓ Success: 10.1186_s13326-019-0195-3.pdf
# Converting 10.1186_s13568-018-0680-6.pdf...
# ✓ Success: 10.1186_s13568-018-0680-6.pdf
# Converting 10.1186_s13617-019-0084-6.pdf...
# ✓ Success: 10.1186_s13617-019-0084-6.pdf
# Converting 10.1186_s13643-018-0859-6.pdf...
# ✓ Success: 10.1186_s13643-018-0859-6.pdf
# Converting 10.1186_s13750-020-0184-0.pdf...
# ✓ Success: 10.1186_s13750-020-0184-0.pdf
# Converting 10.1186_s40168-017-0338-7.pdf...
# ✓ Success: 10.1186_s40168-017-0338-7.pdf
# Converting 10.1186_s40168-018-0532-2.pdf...
# ✓ Success: 10.1186_s40168-018-0532-2.pdf
# Converting 10.1186_s40168-018-0550-0.pdf...
# ✓ Success: 10.1186_s40168-018-0550-0.pdf
# Converting 10.1186_s40169-019-0253-6.pdf...
# ✓ Success: 10.1186_s40169-019-0253-6.pdf
# Converting 10.1186_s40170-018-0185-4.pdf...
# ✓ Success: 10.1186_s40170-018-0185-4.pdf
# Converting 10.1186_s40170-020-00212-x.pdf...
# ✓ Success: 10.1186_s40170-020-00212-x.pdf
# Converting 10.1186_s40425-019-0730-x.pdf...
# ✓ Success: 10.1186_s40425-019-0730-x.pdf
# Converting 10.1186_s40478-018-0561-x.pdf...
# ✓ Success: 10.1186_s40478-018-0561-x.pdf
# Converting 10.1186_s40478-018-0655-5.pdf...
# ✓ Success: 10.1186_s40478-018-0655-5.pdf
# Converting 10.1186_s40657-018-0125-6.pdf...
# ✓ Success: 10.1186_s40657-018-0125-6.pdf
# Converting 10.1186_s40657-020-00194-w.pdf...
# ✓ Success: 10.1186_s40657-020-00194-w.pdf
# Converting 10.1186_s40793-015-0095-9.pdf...
# ✓ Success: 10.1186_s40793-015-0095-9.pdf
# Converting 10.1186_s40851-018-0089-8.pdf...
# ✓ Success: 10.1186_s40851-018-0089-8.pdf
# Converting 10.1212_wnl.0000000000006035.pdf...
# ✓ Success: 10.1212_wnl.0000000000006035.pdf
# Converting 10.1242_bio.035071.pdf...
# ✓ Success: 10.1242_bio.035071.pdf
# Converting 10.1242_dev.138545.pdf...
# ✓ Success: 10.1242_dev.138545.pdf
# Converting 10.1242_jeb.211466.pdf...
# ✓ Success: 10.1242_jeb.211466.pdf
# Converting 10.12688_f1000research.10556.1.pdf...
# ✓ Success: 10.12688_f1000research.10556.1.pdf
# Converting 10.12688_f1000research.11698.1.pdf...
# ✓ Success: 10.12688_f1000research.11698.1.pdf
# Converting 10.12688_f1000research.13064.1.pdf...
# ✓ Success: 10.12688_f1000research.13064.1.pdf
# Converting 10.12688_f1000research.13483.1.pdf...
# ✓ Success: 10.12688_f1000research.13483.1.pdf
# Converting 10.12688_f1000research.13622.1.pdf...
# ✓ Success: 10.12688_f1000research.13622.1.pdf
# Converting 10.12688_f1000research.13852.1.pdf...
# ✓ Success: 10.12688_f1000research.13852.1.pdf
# Converting 10.12688_f1000research.4660.1.pdf...
# ✓ Success: 10.12688_f1000research.4660.1.pdf
# Converting 10.1364_oe.25.001985.pdf...
# ✓ Success: 10.1364_oe.25.001985.pdf
# Converting 10.1371_journal.pcbi.1011828.pdf...
# ✓ Success: 10.1371_journal.pcbi.1011828.pdf
# Converting 10.1371_journal.pntd.0005385.pdf...
# ✓ Success: 10.1371_journal.pntd.0005385.pdf
# Converting 10.1371_journal.pone.0070749.pdf...
# ✓ Success: 10.1371_journal.pone.0070749.pdf
# Converting 10.1371_journal.pone.0093021.pdf...
# ✓ Success: 10.1371_journal.pone.0093021.pdf
# Converting 10.1371_journal.pone.0096457.pdf...
# ✓ Success: 10.1371_journal.pone.0096457.pdf
# Converting 10.1371_journal.pone.0117675.pdf...
# ✓ Success: 10.1371_journal.pone.0117675.pdf
# Converting 10.1371_journal.pone.0137181.pdf...
# ✓ Success: 10.1371_journal.pone.0137181.pdf
# Converting 10.1371_journal.pone.0139215.pdf...
# ✓ Success: 10.1371_journal.pone.0139215.pdf
# Converting 10.1371_journal.pone.0146274.pdf...
# ✓ Success: 10.1371_journal.pone.0146274.pdf
# Converting 10.1371_journal.pone.0159387.pdf...
# ✓ Success: 10.1371_journal.pone.0159387.pdf
# Converting 10.1371_journal.pone.0170126.pdf...
# ✓ Success: 10.1371_journal.pone.0170126.pdf
# Converting 10.1371_journal.pone.0188323.pdf...
# ✓ Success: 10.1371_journal.pone.0188323.pdf
# Converting 10.1371_journal.pone.0191086.pdf...
# ✓ Success: 10.1371_journal.pone.0191086.pdf
# Converting 10.1371_journal.pone.0198382.pdf...
# ✓ Success: 10.1371_journal.pone.0198382.pdf
# Converting 10.1371_journal.pone.0200041.pdf...
# ✓ Success: 10.1371_journal.pone.0200041.pdf
# Converting 10.1371_journal.pone.0212669.pdf...
# ✓ Success: 10.1371_journal.pone.0212669.pdf
# Converting 10.1371_journal.pone.0220399.pdf...
# ✓ Success: 10.1371_journal.pone.0220399.pdf
# Converting 10.1371_journal.pone.0253228.pdf...
# ✓ Success: 10.1371_journal.pone.0253228.pdf
# Converting 10.1371_journal.pone.0262974.pdf...
# ✓ Success: 10.1371_journal.pone.0262974.pdf
# Converting 10.1371_journal.pone.0284951.pdf...
# ✓ Success: 10.1371_journal.pone.0284951.pdf
# Converting 10.14358_pers.22-00039r2.pdf...
# ✓ Success: 10.14358_pers.22-00039r2.pdf
# Converting 10.14379_iodp.proc.390393.208.2024.pdf...
# ✓ Success: 10.14379_iodp.proc.390393.208.2024.pdf
# Converting 10.1534_g3.119.400401.pdf...
# ✓ Success: 10.1534_g3.119.400401.pdf
# Converting 10.1534_g3.119.400993.pdf...
# ✓ Success: 10.1534_g3.119.400993.pdf
# Converting 10.1534_genetics.120.303190.pdf...
# ✓ Success: 10.1534_genetics.120.303190.pdf
# Converting 10.1590_0001-3765201920180768.pdf...
# ✓ Success: 10.1590_0001-3765201920180768.pdf
# Converting 10.1590_0001-3765201920190822.pdf...
# ✓ Success: 10.1590_0001-3765201920190822.pdf
# Converting 10.1590_0034-7167-2018-0065.pdf...
# ✓ Success: 10.1590_0034-7167-2018-0065.pdf
# Converting 10.1590_0034-737x201966050002.pdf...
# ✓ Success: 10.1590_0034-737x201966050002.pdf
# Converting 10.1590_0047-2085000000239.pdf...
# ✓ Success: 10.1590_0047-2085000000239.pdf
# Converting 10.1590_0102-778632120150164.pdf...
# ✓ Success: 10.1590_0102-778632120150164.pdf
# Converting 10.1590_0102-77863220007.pdf...
# ✓ Success: 10.1590_0102-77863220007.pdf
# Converting 10.1590_0102.3772e35417.pdf...
# ✓ Success: 10.1590_0102.3772e35417.pdf
# Converting 10.1590_0103-6351_4070.pdf...
# ✓ Success: 10.1590_0103-6351_4070.pdf
# Converting 10.1590_0103-6440201802861.pdf...
# ✓ Success: 10.1590_0103-6440201802861.pdf
# Converting 10.1590_0104-4060.59642.pdf...
# ✓ Success: 10.1590_0104-4060.59642.pdf
# Converting 10.1590_0104-530x4900-19.pdf...
# ✓ Success: 10.1590_0104-530x4900-19.pdf
# Converting 10.1590_0104-6632.20190362s20180340.pdf...
# ✓ Success: 10.1590_0104-6632.20190362s20180340.pdf
# Converting 10.1590_1413-785220192703169516.pdf...
# ✓ Success: 10.1590_1413-785220192703169516.pdf
# Converting 10.1590_1414-431x20198292.pdf...
# ✓ Success: 10.1590_1414-431x20198292.pdf
# Converting 10.1590_1516-3180.2018.0270071218.pdf...
# ✓ Success: 10.1590_1516-3180.2018.0270071218.pdf
# Converting 10.1590_1517-869220192505126869.pdf...
# ✓ Success: 10.1590_1517-869220192505126869.pdf
# Converting 10.1590_1519-6984.192126.pdf...
# ✓ Success: 10.1590_1519-6984.192126.pdf
# Converting 10.1590_1678-4162-10032.pdf...
# ✓ Success: 10.1590_1678-4162-10032.pdf
# Converting 10.1590_1678-4162-10752.pdf...
# ✓ Success: 10.1590_1678-4162-10752.pdf
# Converting 10.1590_1678-4499.20190067.pdf...
# ✓ Success: 10.1590_1678-4499.20190067.pdf
# Converting 10.1590_1678-4685-gmb-2018-0055.pdf...
# ✓ Success: 10.1590_1678-4685-gmb-2018-0055.pdf
# Converting 10.1590_1679-78255326.pdf...
# ✓ Success: 10.1590_1679-78255326.pdf
# Converting 10.1590_1679-78255753.pdf...
# ✓ Success: 10.1590_1679-78255753.pdf
# Converting 10.1590_1806-90882019000500004.pdf...
# ✓ Success: 10.1590_1806-90882019000500004.pdf
# Converting 10.1590_1806-93042019000400002.pdf...
# ✓ Success: 10.1590_1806-93042019000400002.pdf
# Converting 10.1590_1806-9479.2019.185555.pdf...
# ✓ Success: 10.1590_1806-9479.2019.185555.pdf
# Converting 10.1590_1807-3107bor-2019.vol33.0095.pdf...
# ✓ Success: 10.1590_1807-3107bor-2019.vol33.0095.pdf
# Converting 10.1590_1809-2950_19003927012020.pdf...
# ✓ Success: 10.1590_1809-2950_19003927012020.pdf
# Converting 10.1590_1809-2950_19008627012020.pdf...
# ✓ Success: 10.1590_1809-2950_19008627012020.pdf
# Converting 10.1590_1809-4430-eng.agric.v40n1p24-33_2020.pdf...
# ✓ Success: 10.1590_1809-4430-eng.agric.v40n1p24-33_2020.pdf
# Converting 10.1590_1809-6891v21e-43578.pdf...
# ✓ Success: 10.1590_1809-6891v21e-43578.pdf
# Converting 10.1590_1809-9823.2007.10034.pdf...
# ✓ Success: 10.1590_1809-9823.2007.10034.pdf
# Converting 10.1590_1980-5373-mr-2018-0766.pdf...
# ✓ Success: 10.1590_1980-5373-mr-2018-0766.pdf
# Converting 10.1590_1980-5373-mr-2018-0921.pdf...
# ✓ Success: 10.1590_1980-5373-mr-2018-0921.pdf
# Converting 10.1590_1980-5373-mr-2019-0338.pdf...
# ✓ Success: 10.1590_1980-5373-mr-2019-0338.pdf
# Converting 10.1590_1980-5918.032.ao27.pdf...
# ✓ Success: 10.1590_1980-5918.032.ao27.pdf
# Converting 10.1590_1980-5918.033.ao15.pdf...
# ✓ Success: 10.1590_1980-5918.033.ao15.pdf
# Converting 10.1590_1981-22562019022.190037.pdf...
# ✓ Success: 10.1590_1981-22562019022.190037.pdf
# Converting 10.1590_1981-52712015v43n3rb20180090.pdf...
# ✓ Success: 10.1590_1981-52712015v43n3rb20180090.pdf
# Converting 10.1590_1981-6723.06017.pdf...
# ✓ Success: 10.1590_1981-6723.06017.pdf
# Converting 10.1590_1981-86372019000243506.pdf...
# ✓ Success: 10.1590_1981-86372019000243506.pdf
# Converting 10.1590_1982-0216_20192158519.pdf...
# ✓ Success: 10.1590_1982-0216_20192158519.pdf
# Converting 10.1590_1983-21252019v32n324rc.pdf...
# ✓ Success: 10.1590_1983-21252019v32n324rc.pdf
# Converting 10.1590_2236-3459_83528.pdf...
# ✓ Success: 10.1590_2236-3459_83528.pdf
# Converting 10.1590_2237-6089-2017-0134.pdf...
# ✓ Success: 10.1590_2237-6089-2017-0134.pdf
# Converting 10.1590_fst.33717.pdf...
# ✓ Success: 10.1590_fst.33717.pdf
# Converting 10.1590_fst.36617.pdf...
# ✓ Success: 10.1590_fst.36617.pdf
# Converting 10.1590_s1677-5538.ibju.2019.0167.pdf...
# ✓ Success: 10.1590_s1677-5538.ibju.2019.0167.pdf
# Converting 10.1590_s1678-86212019000400340.pdf...
# ✓ Success: 10.1590_s1678-86212019000400340.pdf
# Converting 10.1617_s11527-023-02260-3.pdf...
# ✓ Success: 10.1617_s11527-023-02260-3.pdf
# Converting 10.17581_bp.2020.09104.pdf...
# ✓ Success: 10.17581_bp.2020.09104.pdf
# Converting 10.17815_jlsrf-2-58.pdf...
# ✓ Success: 10.17815_jlsrf-2-58.pdf
# Converting 10.18438_eblip29674.pdf...
# ✓ Success: 10.18438_eblip29674.pdf
# Converting 10.20944_preprints202009.0353.v1.pdf...
# ✓ Success: 10.20944_preprints202009.0353.v1.pdf
# Converting 10.21105_joss.04237.pdf...
# ✓ Success: 10.21105_joss.04237.pdf
# Converting 10.21203_rs.3.rs-2814013_v1.pdf...
# ✓ Success: 10.21203_rs.3.rs-2814013_v1.pdf
# Converting 10.21203_rs.3.rs-3338732_v1.pdf...
# ✓ Success: 10.21203_rs.3.rs-3338732_v1.pdf
# Converting 10.3133_cir1497.pdf...
# ✓ Success: 10.3133_cir1497.pdf
# Converting 10.3133_fs20233046.pdf...
# ✓ Success: 10.3133_fs20233046.pdf
# Converting 10.3133_ofr20201035.pdf...
# ✓ Success: 10.3133_ofr20201035.pdf
# Converting 10.3133_ofr20231026.pdf...
# ✓ Success: 10.3133_ofr20231026.pdf
# Converting 10.3133_ofr20231027.pdf...
# ✓ Success: 10.3133_ofr20231027.pdf
# Converting 10.3389_fcell.2020.618552.pdf...
# ✓ Success: 10.3389_fcell.2020.618552.pdf
# Converting 10.3389_fchem.2019.00828.pdf...
# ✓ Success: 10.3389_fchem.2019.00828.pdf
# Converting 10.3389_fcimb.2024.1292467.pdf...
# ✓ Success: 10.3389_fcimb.2024.1292467.pdf
# Converting 10.3389_feart.2023.1205211.pdf...
# ✓ Success: 10.3389_feart.2023.1205211.pdf
# Converting 10.3389_fevo.2023.1112519.pdf...
# ✓ Success: 10.3389_fevo.2023.1112519.pdf
# Converting 10.3389_fmicb.2024.1456637.pdf...
# ✓ Success: 10.3389_fmicb.2024.1456637.pdf
# Converting 10.3389_fpls.2023.1160645.pdf...
# ✓ Success: 10.3389_fpls.2023.1160645.pdf
# Converting 10.3390_cryst2031058.pdf...
# ✓ Success: 10.3390_cryst2031058.pdf
# Converting 10.3390_cryst9060301.pdf...
# ✓ Success: 10.3390_cryst9060301.pdf
# Converting 10.3390_d13010019.pdf...
# ✓ Success: 10.3390_d13010019.pdf
# Converting 10.3390_ijms12117360.pdf...
# ✓ Success: 10.3390_ijms12117360.pdf
# Converting 10.3390_inorganics7050058.pdf...
# ✓ Success: 10.3390_inorganics7050058.pdf
# Converting 10.3390_microorganisms8121872.pdf...
# ✓ Success: 10.3390_microorganisms8121872.pdf
# Converting 10.3390_molecules17077645.pdf...
# ✓ Success: 10.3390_molecules17077645.pdf
# Converting 10.3390_molecules191017026.pdf...
# ✓ Success: 10.3390_molecules191017026.pdf
# Converting 10.3390_molecules200917469.pdf...
# ✓ Success: 10.3390_molecules200917469.pdf
# Converting 10.3390_molecules23123199.pdf...
# ✓ Success: 10.3390_molecules23123199.pdf
# Converting 10.3390_molecules25010053.pdf...
# ✓ Success: 10.3390_molecules25010053.pdf
# Converting 10.3390_rs12121957.pdf...
# ✓ Success: 10.3390_rs12121957.pdf
# Converting 10.3390_rs4102923.pdf...
# ✓ Success: 10.3390_rs4102923.pdf
# Converting 10.3390_s19030479.pdf...
# ✓ Success: 10.3390_s19030479.pdf
# Converting 10.3390_s23094491.pdf...
# ✓ Success: 10.3390_s23094491.pdf
# Converting 10.3390_s23177333.pdf...
# ✓ Success: 10.3390_s23177333.pdf
# Converting 10.3390_v11060565.pdf...
# ✓ Success: 10.3390_v11060565.pdf
# Converting 10.3762_bjoc.8.42.pdf...
# ✓ Success: 10.3762_bjoc.8.42.pdf
# Converting 10.3762_bjoc.9.92.pdf...
# ✓ Success: 10.3762_bjoc.9.92.pdf
# Converting 10.3847_1538-4357_aae92c.pdf...
# ✓ Success: 10.3847_1538-4357_aae92c.pdf
# Converting 10.3897_bdj.7.e47369.pdf...
# ✓ Success: 10.3897_bdj.7.e47369.pdf
# Converting 10.3897_jhr.96.111550.pdf...
# ✓ Success: 10.3897_jhr.96.111550.pdf
# Converting 10.3897_neobiota.82.87455.pdf...
# ✓ Success: 10.3897_neobiota.82.87455.pdf
# Converting 10.3897_zookeys.500.9360.pdf...
# ✓ Success: 10.3897_zookeys.500.9360.pdf
# Converting 10.3897_zoologia.35.e23481.pdf...
# ✓ Success: 10.3897_zoologia.35.e23481.pdf
# Converting 10.3897_zoologia.36.e32053.pdf...
# ✓ Success: 10.3897_zoologia.36.e32053.pdf
# Converting 10.4025_actasciagron.v40i1.39392.pdf...
# ✓ Success: 10.4025_actasciagron.v40i1.39392.pdf
# Converting 10.5194_acp-2021-570.pdf...
# ✓ Success: 10.5194_acp-2021-570.pdf
# Converting 10.5194_acp-22-2769-2022.pdf...
# ✓ Success: 10.5194_acp-22-2769-2022.pdf
# Converting 10.5194_acp-22-5701-2022.pdf...
# ✓ Success: 10.5194_acp-22-5701-2022.pdf
# Converting 10.5194_amt-15-3969-2022.pdf...
# ✓ Success: 10.5194_amt-15-3969-2022.pdf
# Converting 10.5194_essd-12-1287-2020.pdf...
# ✓ Success: 10.5194_essd-12-1287-2020.pdf
# Converting 10.5194_essd-2019-206.pdf...
# ✓ Success: 10.5194_essd-2019-206.pdf
# Converting 10.5194_essd-2023-187.pdf...
# ✓ Success: 10.5194_essd-2023-187.pdf
# Converting 10.5194_essd-2023-198.pdf...
# ✓ Success: 10.5194_essd-2023-198.pdf
# Converting 10.5194_essd-8-663-2016.pdf...
# ✓ Success: 10.5194_essd-8-663-2016.pdf
# Converting 10.5194_gmd-12-4221-2019.pdf...
# ✓ Success: 10.5194_gmd-12-4221-2019.pdf
# Converting 10.5194_gmd-13-335-2020.pdf...
# ✓ Success: 10.5194_gmd-13-335-2020.pdf
# Converting 10.5194_se-13-1541-2022.pdf...
# ✓ Success: 10.5194_se-13-1541-2022.pdf
# Converting 10.5194_tc-17-3617-2023.pdf...
# ✓ Success: 10.5194_tc-17-3617-2023.pdf
# Converting 10.5937_bnhmb1811227u.pdf...
# ✓ Success: 10.5937_bnhmb1811227u.pdf
# Converting 10.7554_elife.29944.pdf...
# ✓ Success: 10.7554_elife.29944.pdf
# Converting 10.7554_elife.42722.pdf...
# ✓ Success: 10.7554_elife.42722.pdf
# Converting 10.7554_elife.62329.pdf...
# ✓ Success: 10.7554_elife.62329.pdf
# Converting 10.7554_eLife.63194.pdf...
# ✓ Success: 10.7554_eLife.63194.pdf
# Converting 10.7554_elife.63455.pdf...
# ✓ Success: 10.7554_elife.63455.pdf
# Converting 10.7554_eLife.72626.pdf...
# ✓ Success: 10.7554_eLife.72626.pdf
# Converting 10.7554_elife.73695.pdf...
# ✓ Success: 10.7554_elife.73695.pdf
# Converting 10.7554_elife.74937.pdf...
# ✓ Success: 10.7554_elife.74937.pdf
# Converting 10.7717_peerj.10452.pdf...
# ✓ Success: 10.7717_peerj.10452.pdf
# Converting 10.7717_peerj.11352.pdf...
# ✓ Success: 10.7717_peerj.11352.pdf
# Converting 10.7717_peerj.12422.pdf...
# ✓ Success: 10.7717_peerj.12422.pdf
# Converting 10.7717_peerj.13193.pdf...
# ✓ Success: 10.7717_peerj.13193.pdf
#
# === Summary ===
# Total PDFs found: 524
# Converted: 513
# Failed: 11
# Skipped (already exists): 0

# %% [markdown]
# CONVERSION FROM XML TO JSON

# %%
import os
import xmltodict
import json

# === Configuration ===
xml_folder = r"make-data-count-finding-data-references\train\ALL_XML_FILES"
json_folder = r"make-data-count-finding-data-references\train\all_json_files"

# === Ensure output folder exists ===
os.makedirs(json_folder, exist_ok=True)

# === Process each XML file ===
converted = 0
failed = 0

for filename in os.listdir(xml_folder):
    if not filename.lower().endswith(".xml"):
        continue

    xml_path = os.path.join(xml_folder, filename)
    json_filename = os.path.splitext(filename)[0] + ".json"
    json_path = os.path.join(json_folder, json_filename)

    try:
        with open(xml_path, 'r', encoding='utf-8') as xml_file:
            xml_content = xml_file.read()
            data_dict = xmltodict.parse(xml_content)

        with open(json_path, 'w', encoding='utf-8') as json_file:
            json.dump(data_dict, json_file, indent=2)

        print(f"✓ Converted: {filename}")
        converted += 1

    except Exception as e:
        print(f"✗ Failed to convert {filename}: {e}")
        failed += 1

# === Summary ===
print("\n=== Conversion Summary ===")
print(f"Total XML files: {converted + failed}")
print(f"Converted successfully: {converted}")
print(f"Failed: {failed}")
# Out:
# ✓ Converted: 10.1002_2017jc013030.xml
# ✓ Converted: 10.1002_anie.201916483.xml
# ✓ Converted: 10.1002_anie.202005531.xml
# ✓ Converted: 10.1002_anie.202007717.xml
# ✓ Converted: 10.1002_chem.201902131.xml
# ✓ Converted: 10.1002_chem.201903120.xml
# ✓ Converted: 10.1002_chem.202000235.xml
# ✓ Converted: 10.1002_chem.202001412.xml
# ✓ Converted: 10.1002_chem.202001668.xml
# ✓ Converted: 10.1002_chem.202003167.xml
# ✓ Converted: 10.1002_cssc.202201821.xml
# ✓ Converted: 10.1002_ece3.3985.xml
# ✓ Converted: 10.1002_ece3.4466.xml
# ✓ Converted: 10.1002_ece3.5260.xml
# ✓ Converted: 10.1002_ece3.5395.xml
# ✓ Converted: 10.1002_ece3.6144.xml
# ✓ Converted: 10.1002_ece3.6303.xml
# ✓ Converted: 10.1002_ece3.6784.xml
# ✓ Converted: 10.1002_ece3.961.xml
# ✓ Converted: 10.1002_ece3.9627.xml
# ✓ Converted: 10.1002_ecs2.1280.xml
# ✓ Converted: 10.1002_ecs2.4619.xml
# ✓ Converted: 10.1002_ejic.201900904.xml
# ✓ Converted: 10.1002_ejoc.202000139.xml
# ✓ Converted: 10.1002_ejoc.202000916.xml
# ✓ Converted: 10.1002_esp.5058.xml
# ✓ Converted: 10.1002_esp.5090.xml
# ✓ Converted: 10.1002_mp.14424.xml
# ✓ Converted: 10.1002_nafm.10870.xml
# ✓ Converted: 10.1007_jhep07(2018)134.xml
# ✓ Converted: 10.1007_jhep11(2018)113.xml
# ✓ Converted: 10.1007_jhep11(2018)115.xml
# ✓ Converted: 10.1007_jhep12(2018)117.xml
# ✓ Converted: 10.1007_s00259-022-06053-8.xml
# ✓ Converted: 10.1007_s00382-012-1636-1.xml
# ✓ Converted: 10.1007_s00382-022-06361-7.xml
# ✓ Converted: 10.1007_s00442-022-05201-z.xml
# ✓ Converted: 10.1007_s10904-014-0054-8.xml
# ✓ Converted: 10.1007_s12263-014-0408-4.xml
# ✓ Converted: 10.1007_s12559-020-09751-3.xml
# ✓ Converted: 10.1016_j.ast.2022.107401.xml
# ✓ Converted: 10.1016_j.cpc.2024.109087.xml
# ✓ Converted: 10.1016_j.dib.2022.108797.xml
# ✓ Converted: 10.1016_j.dib.2023.109949.xml
# ✓ Converted: 10.1016_j.ecolind.2021.107934.xml
# ✓ Converted: 10.1016_j.fuel.2022.125768.xml
# ✓ Converted: 10.1016_j.jlp.2022.104761.xml
# ✓ Converted: 10.1016_j.jobe.2023.107105.xml
# ✓ Converted: 10.1016_j.jsames.2022.103824.xml
# ✓ Converted: 10.1016_j.molcel.2018.11.006.xml
# ✓ Converted: 10.1016_j.scitotenv.2024.171850.xml
# ✓ Converted: 10.1016_j.websem.2024.100815.xml
# ✓ Converted: 10.1017_rdc.2022.19.xml
# ✓ Converted: 10.1017_s0007123423000601.xml
# ✓ Converted: 10.1021_acs.jcim.9b01185.xml
# ✓ Converted: 10.1021_acscentsci.1c01109.xml
# ✓ Converted: 10.1021_acsomega.3c06074.xml
# ✓ Converted: 10.1021_jacs.2c06519.xml
# ✓ Converted: 10.1029_2018gl078007.xml
# ✓ Converted: 10.1029_2019jg005297.xml
# ✓ Converted: 10.1029_2019pa003774.xml
# ✓ Converted: 10.1029_2020jf005675.xml
# ✓ Converted: 10.1029_2021ea001703.xml
# ✓ Converted: 10.1029_2021gl096173.xml
# ✓ Converted: 10.1029_2021pa004379.xml
# ✓ Converted: 10.1029_2022gl100473.xml
# ✓ Converted: 10.1029_2023ea002840.xml
# ✓ Converted: 10.1029_2023wr035126.xml
# ✓ Converted: 10.1038_hdy.2013.74.xml
# ✓ Converted: 10.1038_hdy.2014.75.xml
# ✓ Converted: 10.1038_hdy.2015.99.xml
# ✓ Converted: 10.1038_ncomms11871.xml
# ✓ Converted: 10.1038_s41396-020-00885-8.xml
# ✓ Converted: 10.1038_s41437-020-0318-8.xml
# ✓ Converted: 10.1038_s41467-018-04041-x.xml
# ✓ Converted: 10.1038_s41467-018-07681-1.xml
# ✓ Converted: 10.1038_s41467-019-10357-z.xml
# ✓ Converted: 10.1038_s41558-022-01301-z.xml
# ✓ Converted: 10.1038_s41562-021-01247-w.xml
# ✓ Converted: 10.1038_s41597-019-0101-y.xml
# ✓ Converted: 10.1038_s41597-022-01555-4.xml
# ✓ Converted: 10.1038_s41597-023-02280-2.xml
# ✓ Converted: 10.1038_s41598-017-15852-1.xml
# ✓ Converted: 10.1038_s41598-020-59839-x.xml
# ✓ Converted: 10.1038_s41598-021-85671-y.xml
# ✓ Converted: 10.1038_s41598-024-56373-y.xml
# ✓ Converted: 10.1038_s41893-020-0559-9.xml
# ✓ Converted: 10.1038_sdata.2017.167.xml
# ✓ Converted: 10.1039_c5sc01309g.xml
# ✓ Converted: 10.1039_c9ce01020c.xml
# ✓ Converted: 10.1039_c9ra06638a.xml
# ✓ Converted: 10.1039_c9sc02930c.xml
# ✓ Converted: 10.1039_d0dt02130j.xml
# ✓ Converted: 10.1039_d0gc00363h.xml
# ✓ Converted: 10.1039_d0sc01197e.xml
# ✓ Converted: 10.1039_d0sc01518k.xml
# ✓ Converted: 10.1039_d0sc02283g.xml
# ✓ Converted: 10.1039_d0sc02676j.xml
# ✓ Converted: 10.1039_d0sc03604h.xml
# ✓ Converted: 10.1039_d1ee03696c.xml
# ✓ Converted: 10.1039_d2cc00847e.xml
# ✓ Converted: 10.1051_e3sconf_202017220004.xml
# ✓ Converted: 10.1055_s-0039-1693681.xml
# ✓ Converted: 10.1073_pnas.1323607111.xml
# ✓ Converted: 10.1073_pnas.1705601114.xml
# ✓ Converted: 10.1073_pnas.1711872115.xml
# ✓ Converted: 10.1073_pnas.1915395117.xml
# ✓ Converted: 10.1073_pnas.2306723120.xml
# ✓ Converted: 10.1080_01621459.2019.1573732.xml
# ✓ Converted: 10.1080_02713683.2019.1607392.xml
# ✓ Converted: 10.1080_0284186x.2019.1669817.xml
# ✓ Converted: 10.1080_0284186x.2020.1714721.xml
# ✓ Converted: 10.1080_07350015.2020.1766469.xml
# ✓ Converted: 10.1080_13501763.2019.1630470.xml
# ✓ Converted: 10.1080_14756366.2020.1740692.xml
# ✓ Converted: 10.1080_15476286.2016.1232238.xml
# ✓ Converted: 10.1080_19475683.2023.2226196.xml
# ✓ Converted: 10.1080_21645515.2023.2189598.xml
# ✓ Converted: 10.1080_22221751.2020.1738277.xml
# ✓ Converted: 10.1093_beheco_arad016.xml
# ✓ Converted: 10.1093_beheco_arw167.xml
# ✓ Converted: 10.1093_beheco_arz101.xml
# ✓ Converted: 10.1093_bib_bbab395.xml
# ✓ Converted: 10.1093_evolut_qpad206.xml
# ✓ Converted: 10.1093_nar_gkp1049.xml
# ✓ Converted: 10.1093_sysbio_syy011.xml
# ✓ Converted: 10.1098_rsbl.2015.0113.xml
# ✓ Converted: 10.1098_rsos.160417.xml
# ✓ Converted: 10.1098_rsos.170796.xml
# ✓ Converted: 10.1098_rsos.190841.xml
# ✓ Converted: 10.1098_rsos.210982.xml
# ✓ Converted: 10.1098_rspb.2015.0371.xml
# ✓ Converted: 10.1098_rspb.2015.1498.xml
# ✓ Converted: 10.1098_rspb.2015.2726.xml
# ✓ Converted: 10.1098_rspb.2015.2764.xml
# ✓ Converted: 10.1101_096297.xml
# ✓ Converted: 10.1101_2022.02.10.480011.xml
# ✓ Converted: 10.1101_2022.07.21.501061.xml
# ✓ Converted: 10.1103_physrevresearch.4.023008.xml
# ✓ Converted: 10.1107_s0108270106019688.xml
# ✓ Converted: 10.1107_s1600536807066780.xml
# ✓ Converted: 10.1107_s1600536808011148.xml
# ✓ Converted: 10.1107_s1600536809014883.xml
# ✓ Converted: 10.1107_s1600536809022582.xml
# ✓ Converted: 10.1107_s1600536809043700.xml
# ✓ Converted: 10.1107_s1600536810036299.xml
# ✓ Converted: 10.1107_s1600536810047185.xml
# ✓ Converted: 10.1107_s1600536811003163.xml
# ✓ Converted: 10.1107_s160053681102201x.xml
# ✓ Converted: 10.1107_s160053681103220x.xml
# ✓ Converted: 10.1107_s1600536811042164.xml
# ✓ Converted: 10.1107_s1600536812014614.xml
# ✓ Converted: 10.1107_s1600536812019885.xml
# ✓ Converted: 10.1107_s1600536812024269.xml
# ✓ Converted: 10.1107_s1600536812027390.xml
# ✓ Converted: 10.1107_s1600536812046892.xml
# ✓ Converted: 10.1107_s2052252514012081.xml
# ✓ Converted: 10.1107_s2052252515010271.xml
# ✓ Converted: 10.1107_s2052252515011665.xml
# ✓ Converted: 10.1107_s2052252515023945.xml
# ✓ Converted: 10.1107_s2052252520013603.xml
# ✓ Converted: 10.1107_s2053229620003757.xml
# ✓ Converted: 10.1107_s2056989014026358.xml
# ✓ Converted: 10.1107_s2056989015010257.xml
# ✓ Converted: 10.1107_s2056989015019891.xml
# ✓ Converted: 10.1107_s2056989016016819.xml
# ✓ Converted: 10.1107_s2056989020010658.xml
# ✓ Converted: 10.1107_s2059798322005691.xml
# ✓ Converted: 10.1107_s2414314616000523.xml
# ✓ Converted: 10.1107_s2414314616007033.xml
# ✓ Converted: 10.1107_s2414314616007227.xml
# ✓ Converted: 10.1107_s2414314619012446.xml
# ✓ Converted: 10.1109_access.2024.3385658.xml
# ✓ Converted: 10.1111_1365-2435.13087.xml
# ✓ Converted: 10.1111_1365-2435.13431.xml
# ✓ Converted: 10.1111_1365-2435.13569.xml
# ✓ Converted: 10.1111_1365-2656.12382.xml
# ✓ Converted: 10.1111_1365-2656.12491.xml
# ✓ Converted: 10.1111_1365-2656.12501.xml
# ✓ Converted: 10.1111_1365-2656.12594.xml
# ✓ Converted: 10.1111_1365-2664.13128.xml
# ✓ Converted: 10.1111_1365-2664.13136.xml
# ✓ Converted: 10.1111_1365-2664.13168.xml
# ✓ Converted: 10.1111_1365-2664.13446.xml
# ✓ Converted: 10.1111_1365-2745.13449.xml
# ✓ Converted: 10.1111_2041-210x.12453.xml
# ✓ Converted: 10.1111_2041-210x.13817.xml
# ✓ Converted: 10.1111_acel.13089.xml
# ✓ Converted: 10.1111_bph.14747.xml
# ✓ Converted: 10.1111_cas.12935.xml
# ✓ Converted: 10.1111_ddi.13153.xml
# ✓ Converted: 10.1111_ddi.13161.xml
# ✓ Converted: 10.1111_ejn.13855.xml
# ✓ Converted: 10.1111_eva.12151.xml
# ✓ Converted: 10.1111_eva.12446.xml
# ✓ Converted: 10.1111_eva.12768.xml
# ✓ Converted: 10.1111_evo.13972.xml
# ✓ Converted: 10.1111_gcb.13914.xml
# ✓ Converted: 10.1111_gcb.14974.xml
# ✓ Converted: 10.1111_ggr.12517.xml
# ✓ Converted: 10.1111_mec.16743.xml
# ✓ Converted: 10.1111_mec.16977.xml
# ✓ Converted: 10.1111_njb.02077.xml
# ✓ Converted: 10.1128_JVI.01717-21.xml
# ✓ Converted: 10.1128_spectrum.00422-24.xml
# ✓ Converted: 10.1130_ges01387.1.xml
# ✓ Converted: 10.1136_jitc-2021-003114.xml
# ✓ Converted: 10.1140_epjc_s10052-016-4366-4.xml
# ✓ Converted: 10.1140_epjc_s10052-018-6033-4.xml
# ✓ Converted: 10.1140_epjc_s10052-018-6468-7.xml
# ✓ Converted: 10.1140_epjc_s10052-019-6583-0.xml
# ✓ Converted: 10.1140_epjds_s13688-018-0132-1.xml
# ✓ Converted: 10.1145_3461702.3462538.xml
# ✓ Converted: 10.1155_2013_536562.xml
# ✓ Converted: 10.1177_0018720820970751.xml
# ✓ Converted: 10.1186_1471-244x-13-259.xml
# ✓ Converted: 10.1186_1752-153x-7-123.xml
# ✓ Converted: 10.1186_gb-2010-11-10-r101.xml
# ✓ Converted: 10.1186_s11658-018-0120-2.xml
# ✓ Converted: 10.1186_s11689-019-9287-8.xml
# ✓ Converted: 10.1186_s12859-016-0904-1.xml
# ✓ Converted: 10.1186_s12859-016-0922-z.xml
# ✓ Converted: 10.1186_s12859-016-0938-4.xml
# ✓ Converted: 10.1186_s12859-016-1206-3.xml
# ✓ Converted: 10.1186_s12859-017-1563-6.xml
# ✓ Converted: 10.1186_s12859-017-1952-x.xml
# ✓ Converted: 10.1186_s12859-018-2036-2.xml
# ✓ Converted: 10.1186_s12859-018-2146-x.xml
# ✓ Converted: 10.1186_s12859-018-2263-6.xml
# ✓ Converted: 10.1186_s12859-018-2414-9.xml
# ✓ Converted: 10.1186_s12859-020-3415-z.xml
# ✓ Converted: 10.1186_s12859-020-3496-8.xml
# ✓ Converted: 10.1186_s12860-020-00261-6.xml
# ✓ Converted: 10.1186_s12862-015-0558-z.xml
# ✓ Converted: 10.1186_s12862-018-1213-2.xml
# ✓ Converted: 10.1186_s12862-019-1388-1.xml
# ✓ Converted: 10.1186_s12862-019-1509-x.xml
# ✓ Converted: 10.1186_s12863-017-0513-7.xml
# ✓ Converted: 10.1186_s12863-019-0790-4.xml
# ✓ Converted: 10.1186_s12864-015-2206-9.xml
# ✓ Converted: 10.1186_s12864-018-4947-8.xml
# ✓ Converted: 10.1186_s12864-018-5054-6.xml
# ✓ Converted: 10.1186_s12864-018-5198-4.xml
# ✓ Converted: 10.1186_s12864-019-5872-1.xml
# ✓ Converted: 10.1186_s12864-019-6099-x.xml
# ✓ Converted: 10.1186_s12864-019-6131-1.xml
# ✓ Converted: 10.1186_s12864-019-6324-7.xml
# ✓ Converted: 10.1186_s12864-020-6657-2.xml
# ✓ Converted: 10.1186_s12866-015-0509-2.xml
# ✓ Converted: 10.1186_s12866-019-1542-3.xml
# ✓ Converted: 10.1186_s12866-020-01863-y.xml
# ✓ Converted: 10.1186_s12868-018-0468-2.xml
# ✓ Converted: 10.1186_s12868-019-0514-8.xml
# ✓ Converted: 10.1186_s12870-018-1332-3.xml
# ✓ Converted: 10.1186_s12870-018-1542-8.xml
# ✓ Converted: 10.1186_s12870-019-1632-2.xml
# ✓ Converted: 10.1186_s12870-019-1889-5.xml
# ✓ Converted: 10.1186_s12870-019-1904-x.xml
# ✓ Converted: 10.1186_s12870-019-1926-4.xml
# ✓ Converted: 10.1186_s12870-019-2199-7.xml
# ✓ Converted: 10.1186_s12870-020-02651-6.xml
# ✓ Converted: 10.1186_s12870-020-02692-x.xml
# ✓ Converted: 10.1186_s12870-020-2295-8.xml
# ✓ Converted: 10.1186_s12874-018-0583-x.xml
# ✓ Converted: 10.1186_s12874-019-0829-2.xml
# ✓ Converted: 10.1186_s12879-018-3065-1.xml
# ✓ Converted: 10.1186_s12879-019-3766-0.xml
# ✓ Converted: 10.1186_s12881-019-0773-3.xml
# ✓ Converted: 10.1186_s12882-019-1494-8.xml
# ✓ Converted: 10.1186_s12884-018-1751-z.xml
# ✓ Converted: 10.1186_s12885-017-3237-1.xml
# ✓ Converted: 10.1186_s12885-018-4229-5.xml
# ✓ Converted: 10.1186_s12885-018-4314-9.xml
# ✓ Converted: 10.1186_s12885-018-4768-9.xml
# ✓ Converted: 10.1186_s12885-019-5681-6.xml
# ✓ Converted: 10.1186_s12885-020-06724-5.xml
# ✓ Converted: 10.1186_s12903-018-0656-6.xml
# ✓ Converted: 10.1186_s12906-019-2769-0.xml
# ✓ Converted: 10.1186_s12913-018-3333-1.xml
# ✓ Converted: 10.1186_s12915-018-0498-3.xml
# ✓ Converted: 10.1186_s12915-018-0584-6.xml
# ✓ Converted: 10.1186_s12916-019-1469-4.xml
# ✓ Converted: 10.1186_s12918-015-0209-4.xml
# ✓ Converted: 10.1186_s12918-018-0564-z.xml
# ✓ Converted: 10.1186_s12918-018-0620-8.xml
# ✓ Converted: 10.1186_s12920-018-0379-1.xml
# ✓ Converted: 10.1186_s12920-018-0403-5.xml
# ✓ Converted: 10.1186_s12920-018-0426-y.xml
# ✓ Converted: 10.1186_s12920-019-0611-7.xml
# ✓ Converted: 10.1186_s12920-019-0628-y.xml
# ✓ Converted: 10.1186_s12920-019-0646-9.xml
# ✓ Converted: 10.1186_s12920-020-00737-6.xml
# ✓ Converted: 10.1186_s12931-019-1001-6.xml
# ✓ Converted: 10.1186_s12933-019-0813-5.xml
# ✓ Converted: 10.1186_s12934-018-1005-9.xml
# ✓ Converted: 10.1186_s12935-020-01373-x.xml
# ✓ Converted: 10.1186_s12943-018-0878-x.xml
# ✓ Converted: 10.1186_s12943-019-1017-z.xml
# ✓ Converted: 10.1186_s12967-019-2100-3.xml
# ✓ Converted: 10.1186_s12967-020-02311-1.xml
# ✓ Converted: 10.1186_s12974-020-01860-y.xml
# ✓ Converted: 10.1186_s12977-015-0204-2.xml
# ✓ Converted: 10.1186_s13007-019-0403-2.xml
# ✓ Converted: 10.1186_s13014-018-1166-z.xml
# ✓ Converted: 10.1186_s13020-020-00307-z.xml
# ✓ Converted: 10.1186_s13024-018-0254-8.xml
# ✓ Converted: 10.1186_s13024-018-0266-4.xml
# ✓ Converted: 10.1186_s13039-022-00631-z.xml
# ✓ Converted: 10.1186_s13046-018-0843-y.xml
# ✓ Converted: 10.1186_s13054-015-0738-7.xml
# ✓ Converted: 10.1186_s13054-015-1052-0.xml
# ✓ Converted: 10.1186_s13054-019-2488-4.xml
# ✓ Converted: 10.1186_s13058-015-0618-8.xml
# ✓ Converted: 10.1186_s13059-017-1200-8.xml
# ✓ Converted: 10.1186_s13059-018-1557-3.xml
# ✓ Converted: 10.1186_s13059-019-1749-5.xml
# ✓ Converted: 10.1186_s13059-019-1840-y.xml
# ✓ Converted: 10.1186_s13059-019-1908-8.xml
# ✓ Converted: 10.1186_s13059-019-1918-6.xml
# ✓ Converted: 10.1186_s13059-019-1924-8.xml
# ✓ Converted: 10.1186_s13059-020-02048-6.xml
# ✓ Converted: 10.1186_s13059-020-1949-z.xml
# ✓ Converted: 10.1186_s13068-017-0901-2.xml
# ✓ Converted: 10.1186_s13068-018-1078-z.xml
# ✓ Converted: 10.1186_s13068-018-1167-z.xml
# ✓ Converted: 10.1186_s13068-018-1316-4.xml
# ✓ Converted: 10.1186_s13071-016-1359-y.xml
# ✓ Converted: 10.1186_s13071-018-2842-4.xml
# ✓ Converted: 10.1186_s13071-018-2964-8.xml
# ✓ Converted: 10.1186_s13071-018-3084-1.xml
# ✓ Converted: 10.1186_s13071-018-3237-2.xml
# ✓ Converted: 10.1186_s13072-019-0285-6.xml
# ✓ Converted: 10.1186_s13072-019-0322-5.xml
# ✓ Converted: 10.1186_s13073-019-0674-2.xml
# ✓ Converted: 10.1186_s13073-019-0709-8.xml
# ✓ Converted: 10.1186_s13073-020-00727-4.xml
# ✓ Converted: 10.1186_s13100-019-0153-8.xml
# ✓ Converted: 10.1186_s13104-018-4014-1.xml
# ✓ Converted: 10.1186_s13104-019-4058-x.xml
# ✓ Converted: 10.1186_s13104-019-4127-1.xml
# ✓ Converted: 10.1186_s13148-018-0581-1.xml
# ✓ Converted: 10.1186_s13148-019-0719-9.xml
# ✓ Converted: 10.1186_s13321-015-0110-6.xml
# ✓ Converted: 10.1186_s13321-017-0223-1.xml
# ✓ Converted: 10.1186_s13321-017-0246-7.xml
# ✓ Converted: 10.1186_s13321-018-0298-3.xml
# ✓ Converted: 10.1186_s13326-019-0195-3.xml
# ✓ Converted: 10.1186_s13568-018-0680-6.xml
# ✓ Converted: 10.1186_s13617-019-0084-6.xml
# ✓ Converted: 10.1186_s13643-018-0859-6.xml
# ✓ Converted: 10.1186_s13750-020-0184-0.xml
# ✓ Converted: 10.1186_s40168-017-0338-7.xml
# ✓ Converted: 10.1186_s40168-018-0532-2.xml
# ✓ Converted: 10.1186_s40168-018-0550-0.xml
# ✓ Converted: 10.1186_s40169-019-0253-6.xml
# ✓ Converted: 10.1186_s40170-018-0185-4.xml
# ✓ Converted: 10.1186_s40170-020-00212-x.xml
# ✓ Converted: 10.1186_s40425-019-0730-x.xml
# ✓ Converted: 10.1186_s40478-018-0561-x.xml
# ✓ Converted: 10.1186_s40478-018-0655-5.xml
# ✓ Converted: 10.1186_s40657-018-0125-6.xml
# ✓ Converted: 10.1186_s40657-020-00194-w.xml
# ✓ Converted: 10.1186_s40793-015-0095-9.xml
# ✓ Converted: 10.1186_s40851-018-0089-8.xml
# ✓ Converted: 10.1212_wnl.0000000000006035.xml
# ✓ Converted: 10.1242_bio.035071.xml
# ✓ Converted: 10.1242_dev.138545.xml
# ✓ Converted: 10.1242_jeb.211466.xml
# ✓ Converted: 10.12688_f1000research.10556.1.xml
# ✓ Converted: 10.12688_f1000research.11698.1.xml
# ✓ Converted: 10.12688_f1000research.13064.1.xml
# ✓ Converted: 10.12688_f1000research.13483.1.xml
# ✓ Converted: 10.12688_f1000research.13622.1.xml
# ✓ Converted: 10.12688_f1000research.13852.1.xml
# ✓ Converted: 10.12688_f1000research.4660.1.xml
# ✓ Converted: 10.1364_oe.25.001985.xml
# ✓ Converted: 10.1371_journal.pcbi.1011828.xml
# ✓ Converted: 10.1371_journal.pntd.0005385.xml
# ✓ Converted: 10.1371_journal.pone.0070749.xml
# ✓ Converted: 10.1371_journal.pone.0093021.xml
# ✓ Converted: 10.1371_journal.pone.0096457.xml
# ✓ Converted: 10.1371_journal.pone.0117675.xml
# ✓ Converted: 10.1371_journal.pone.0137181.xml
# ✓ Converted: 10.1371_journal.pone.0139215.xml
# ✓ Converted: 10.1371_journal.pone.0146274.xml
# ✓ Converted: 10.1371_journal.pone.0159387.xml
# ✓ Converted: 10.1371_journal.pone.0170126.xml
# ✓ Converted: 10.1371_journal.pone.0188323.xml
# ✓ Converted: 10.1371_journal.pone.0191086.xml
# ✓ Converted: 10.1371_journal.pone.0198382.xml
# ✓ Converted: 10.1371_journal.pone.0200041.xml
# ✓ Converted: 10.1371_journal.pone.0212669.xml
# ✓ Converted: 10.1371_journal.pone.0220399.xml
# ✓ Converted: 10.1371_journal.pone.0253228.xml
# ✓ Converted: 10.1371_journal.pone.0262974.xml
# ✓ Converted: 10.1371_journal.pone.0284951.xml
# ✓ Converted: 10.14358_pers.22-00039r2.xml
# ✓ Converted: 10.14379_iodp.proc.390393.208.2024.xml
# ✓ Converted: 10.1534_g3.119.400401.xml
# ✓ Converted: 10.1534_g3.119.400993.xml
# ✓ Converted: 10.1534_genetics.120.303190.xml
# ✓ Converted: 10.1590_0001-3765201920180768.xml
# ✓ Converted: 10.1590_0001-3765201920190822.xml
# ✓ Converted: 10.1590_0034-7167-2018-0065.xml
# ✓ Converted: 10.1590_0034-737x201966050002.xml
# ✓ Converted: 10.1590_0047-2085000000239.xml
# ✓ Converted: 10.1590_0102-778632120150164.xml
# ✓ Converted: 10.1590_0102-77863220007.xml
# ✓ Converted: 10.1590_0102.3772e35417.xml
# ✓ Converted: 10.1590_0103-6351_4070.xml
# ✓ Converted: 10.1590_0103-6440201802861.xml
# ✓ Converted: 10.1590_0104-4060.59642.xml
# ✓ Converted: 10.1590_0104-530x4900-19.xml
# ✓ Converted: 10.1590_0104-6632.20190362s20180340.xml
# ✓ Converted: 10.1590_1413-785220192703169516.xml
# ✓ Converted: 10.1590_1414-431x20198292.xml
# ✓ Converted: 10.1590_1516-3180.2018.0270071218.xml
# ✓ Converted: 10.1590_1517-869220192505126869.xml
# ✓ Converted: 10.1590_1519-6984.192126.xml
# ✓ Converted: 10.1590_1678-4162-10032.xml
# ✓ Converted: 10.1590_1678-4162-10752.xml
# ✓ Converted: 10.1590_1678-4499.20190067.xml
# ✓ Converted: 10.1590_1678-4685-gmb-2018-0055.xml
# ✓ Converted: 10.1590_1679-78255326.xml
# ✓ Converted: 10.1590_1679-78255753.xml
# ✓ Converted: 10.1590_1806-90882019000500004.xml
# ✓ Converted: 10.1590_1806-93042019000400002.xml
# ✓ Converted: 10.1590_1806-9479.2019.185555.xml
# ✓ Converted: 10.1590_1807-3107bor-2019.vol33.0095.xml
# ✓ Converted: 10.1590_1809-2950_19003927012020.xml
# ✓ Converted: 10.1590_1809-2950_19008627012020.xml
# ✓ Converted: 10.1590_1809-4430-eng.agric.v40n1p24-33_2020.xml
# ✓ Converted: 10.1590_1809-6891v21e-43578.xml
# ✓ Converted: 10.1590_1809-9823.2007.10034.xml
# ✓ Converted: 10.1590_1980-5373-mr-2018-0766.xml
# ✓ Converted: 10.1590_1980-5373-mr-2018-0921.xml
# ✓ Converted: 10.1590_1980-5373-mr-2019-0338.xml
# ✓ Converted: 10.1590_1980-5918.032.ao27.xml
# ✓ Converted: 10.1590_1980-5918.033.ao15.xml
# ✓ Converted: 10.1590_1981-22562019022.190037.xml
# ✓ Converted: 10.1590_1981-52712015v43n3rb20180090.xml
# ✓ Converted: 10.1590_1981-6723.06017.xml
# ✓ Converted: 10.1590_1981-86372019000243506.xml
# ✓ Converted: 10.1590_1982-0216_20192158519.xml
# ✓ Converted: 10.1590_1983-21252019v32n324rc.xml
# ✓ Converted: 10.1590_2236-3459_83528.xml
# ✓ Converted: 10.1590_2237-6089-2017-0134.xml
# ✓ Converted: 10.1590_fst.33717.xml
# ✓ Converted: 10.1590_fst.36617.xml
# ✓ Converted: 10.1590_s1677-5538.ibju.2019.0167.xml
# ✓ Converted: 10.1590_s1678-86212019000400340.xml
# ✓ Converted: 10.1617_s11527-023-02260-3.xml
# ✓ Converted: 10.17581_bp.2020.09104.xml
# ✓ Converted: 10.17815_jlsrf-2-58.xml
# ✓ Converted: 10.18438_eblip29674.xml
# ✓ Converted: 10.20944_preprints202009.0353.v1.xml
# ✓ Converted: 10.21105_joss.04237.xml
# ✓ Converted: 10.21203_rs.3.rs-2814013_v1.xml
# ✓ Converted: 10.21203_rs.3.rs-3338732_v1.xml
# ✓ Converted: 10.3133_cir1497.xml
# ✓ Converted: 10.3133_fs20233046.xml
# ✓ Converted: 10.3133_ofr20201035.xml
# ✓ Converted: 10.3133_ofr20231026.xml
# ✓ Converted: 10.3133_ofr20231027.xml
# ✓ Converted: 10.3389_fcell.2020.618552.xml
# ✓ Converted: 10.3389_fchem.2019.00828.xml
# ✓ Converted: 10.3389_fcimb.2024.1292467.xml
# ✓ Converted: 10.3389_feart.2023.1205211.xml
# ✓ Converted: 10.3389_fevo.2023.1112519.xml
# ✓ Converted: 10.3389_fmicb.2024.1456637.xml
# ✓ Converted: 10.3389_fpls.2023.1160645.xml
# ✓ Converted: 10.3390_cryst2031058.xml
# ✓ Converted: 10.3390_cryst9060301.xml
# ✓ Converted: 10.3390_d13010019.xml
# ✓ Converted: 10.3390_ijms12117360.xml
# ✓ Converted: 10.3390_inorganics7050058.xml
# ✓ Converted: 10.3390_microorganisms8121872.xml
# ✓ Converted: 10.3390_molecules17077645.xml
# ✓ Converted: 10.3390_molecules191017026.xml
# ✓ Converted: 10.3390_molecules200917469.xml
# ✓ Converted: 10.3390_molecules23123199.xml
# ✓ Converted: 10.3390_molecules25010053.xml
# ✓ Converted: 10.3390_rs12121957.xml
# ✓ Converted: 10.3390_rs4102923.xml
# ✓ Converted: 10.3390_s19030479.xml
# ✓ Converted: 10.3390_s23094491.xml
# ✓ Converted: 10.3390_s23177333.xml
# ✓ Converted: 10.3390_v11060565.xml
# ✓ Converted: 10.3762_bjoc.8.42.xml
# ✓ Converted: 10.3762_bjoc.9.92.xml
# ✓ Converted: 10.3847_1538-4357_aae92c.xml
# ✓ Converted: 10.3897_bdj.7.e47369.xml
# ✓ Converted: 10.3897_jhr.96.111550.xml
# ✓ Converted: 10.3897_neobiota.82.87455.xml
# ✓ Converted: 10.3897_zookeys.500.9360.xml
# ✓ Converted: 10.3897_zoologia.35.e23481.xml
# ✓ Converted: 10.3897_zoologia.36.e32053.xml
# ✓ Converted: 10.4025_actasciagron.v40i1.39392.xml
# ✓ Converted: 10.5194_acp-2021-570.xml
# ✓ Converted: 10.5194_acp-22-2769-2022.xml
# ✓ Converted: 10.5194_acp-22-5701-2022.xml
# ✓ Converted: 10.5194_amt-15-3969-2022.xml
# ✓ Converted: 10.5194_essd-12-1287-2020.xml
# ✓ Converted: 10.5194_essd-2019-206.xml
# ✓ Converted: 10.5194_essd-2023-187.xml
# ✓ Converted: 10.5194_essd-2023-198.xml
# ✓ Converted: 10.5194_essd-8-663-2016.xml
# ✓ Converted: 10.5194_gmd-12-4221-2019.xml
# ✓ Converted: 10.5194_gmd-13-335-2020.xml
# ✓ Converted: 10.5194_se-13-1541-2022.xml
# ✓ Converted: 10.5194_tc-17-3617-2023.xml
# ✓ Converted: 10.5937_bnhmb1811227u.xml
# ✓ Converted: 10.7554_elife.29944.xml
# ✓ Converted: 10.7554_elife.42722.xml
# ✓ Converted: 10.7554_elife.62329.xml
# ✓ Converted: 10.7554_eLife.63194.xml
# ✓ Converted: 10.7554_elife.63455.xml
# ✓ Converted: 10.7554_eLife.72626.xml
# ✓ Converted: 10.7554_elife.73695.xml
# ✓ Converted: 10.7554_elife.74937.xml
# ✓ Converted: 10.7717_peerj.10452.xml
# ✓ Converted: 10.7717_peerj.11352.xml
# ✓ Converted: 10.7717_peerj.12422.xml
# ✓ Converted: 10.7717_peerj.13193.xml
#
# === Conversion Summary ===
# Total XML files: 524
# Converted successfully: 524
# Failed: 0

# %% [markdown]
# REGEX PATTERN ONLY

# %%
import os
import json
import re
import pandas as pd
from nltk.tokenize import sent_tokenize
from tqdm import tqdm

# === Paths ===
JSON_DIR = r"make-data-count-finding-data-references/train/all_json_files"

# === Dataset Regex Patterns ===
DATASET_PATTERNS = [
    r'10\.\d{4,9}/[-._;()/:a-z0-9]+',       # DOIs
    r'doi:10\.\d{4,9}/[-._;()/:a-z0-9]+',   # doi: prefix
    r'\bgse\d{4,6}\b', r'\bsrp\d+\b', r'\bsrx\d+\b', r'\bsrr\d+\b', r'\berr\d+\b',
    r'\bdrr\d+\b', r'\be-mexp-\d+\b', r'\be-geod-\d+\b',
    r'\bens[a-z]{0,5}\d+\b', r'\bnm_\d+\b', r'\brs\d+\b',
    r'\bhgnc:\d+\b', r'\b[opq][0-9][a-z0-9]{3}[0-9]\b',
    r'\bmodel\d+\b', r'\bepi_isl_\d+\b', r'\bchembl\d+\b', r'\bmgyp\d+\b',
    r'\bempiar-?\d+\b', r'\bprjna\d+\b', r'\bsamn\d+\b', r'\bpxd\d+\b',
    r'\bku\d+\b', r'\bcvcl_\d+\b', r'\bcab\d+\b', r'\bhpa\d+\b',
    r'\be-prot-\d+\b',
    r'\b[A-Z]{1,2}\d{6}(?:\.\d+)?\b',       # GenBank accessions (e.g., MH714866)
    r'\b\d+\.\d+\.\d+\.\d+\b'               # IP-like or version numbers
]
regex_combined = re.compile("|".join(DATASET_PATTERNS), re.IGNORECASE)

# === Dataset-related keywords
DATASET_KEYWORDS = [
    "dataset", "data available", "accession number", "repository",
    "deposited", "submitted to", "released", "archive", "downloaded from",
    "data were deposited", "data can be accessed", "hosted in", "publicly available"
]

def contains_keyword(text):
    text = text.lower()
    return any(keyword in text for keyword in DATASET_KEYWORDS)

# === Pre-clean broken patterns like `doi. org` → `doi.org`
def clean_text(text):
    text = re.sub(r'doi\s*\.\s*org', 'doi.org', text, flags=re.IGNORECASE)
    text = re.sub(r'https?\s*:\s*/\s*/\s*doi\s*\.\s*org', 'https://doi.org', text, flags=re.IGNORECASE)
    text = re.sub(r'10\s*\.\s*(\d+)', r'10.\1', text)
    return text

# === Extract all string values recursively from JSON
def extract_strings_from_json(obj):
    if isinstance(obj, dict):
        for v in obj.values():
            yield from extract_strings_from_json(v)
    elif isinstance(obj, list):
        for item in obj:
            yield from extract_strings_from_json(item)
    elif isinstance(obj, str):
        yield obj

# === Filtering Function for Invalid Matches
def is_valid_dataset_id(match, sentence):
    if re.fullmatch(r"(19|20)\d{2}", match):  # year
        return False
    if re.fullmatch(r"\d+\.\d+\.\d+\.\d+", match):  # IP or version
        if re.search(r"(v|version)[\s:=]*" + re.escape(match), sentence, re.IGNORECASE):
            return False
    if match.isdigit() and len(match) <= 3:
        return False
    if re.fullmatch(r"\d{4}-\d{2}-\d{2}", match):  # date
        return False
    return True

# === Main Dataset Detection
results = []

for filename in tqdm(os.listdir(JSON_DIR)):
    if not filename.endswith(".json"):
        continue
    path = os.path.join(JSON_DIR, filename)
    article_id = filename.replace(".json", "")

    try:
        with open(path, "r", encoding="utf-8") as f:
            data = json.load(f)
    except Exception as e:
        print(f"❌ Error in {filename}: {e}")
        continue

    all_strings = list(extract_strings_from_json(data))

    for raw_text in all_strings:
        cleaned_text = clean_text(raw_text)
        for sent in sent_tokenize(cleaned_text):
            matches = regex_combined.findall(sent)
            valid_matches = [m for m in matches if is_valid_dataset_id(m, sent)]
            if valid_matches:
                results.append({
                    "article_id": article_id,
                    "sentence": sent.strip(),
                    "dataset_id": "; ".join(sorted(set(valid_matches)))
                })

# === Save to CSV
df = pd.DataFrame(results)
df.to_csv("dataset_mentions_train.csv", index=False)
print(f"✅ Extracted {len(df)} dataset sentences after filtering. Saved to dataset_mentions_train.csv")
# Out:
# 100%|██████████| 524/524 [01:01<00:00,  8.58it/s]
# ✅ Extracted 27428 dataset sentences after filtering. Saved to dataset_mentions_train.csv

# %% [markdown]
# PDF TO XML FOR TEST

# %%
import os
import requests

# === Configuration ===
PDF_FOLDER = r"make-data-count-finding-data-references\test\PDF"
XML_FOLDER = r"make-data-count-finding-data-references\test\PDF_TO_XML"
GROBID_URL = "http://localhost:8070/api/processFulltextDocument"

# === Statistics ===
success_count = 0
fail_count = 0
skipped_count = 0

# === Ensure output folder exists ===
os.makedirs(XML_FOLDER, exist_ok=True)

# === Process each PDF file ===
for pdf_file in os.listdir(PDF_FOLDER):
    if not pdf_file.lower().endswith(".pdf"):
        continue

    pdf_path = os.path.join(PDF_FOLDER, pdf_file)
    xml_filename = os.path.splitext(pdf_file)[0] + ".xml"
    xml_path = os.path.join(XML_FOLDER, xml_filename)

    # Skip if XML already exists
    if os.path.exists(xml_path):
        print(f"Skipping {pdf_file} (already converted)")
        skipped_count += 1
        continue

    print(f"Converting {pdf_file}...")

    try:
        with open(pdf_path, "rb") as f:
            response = requests.post(
                GROBID_URL,
                files={"input": f},
                timeout=60
            )

        if response.status_code == 200:
            with open(xml_path, "w", encoding="utf-8") as out_file:
                out_file.write(response.text)
            print(f"✓ Success: {pdf_file}")
            success_count += 1
        else:
            print(f"✗ Failed (HTTP {response.status_code}): {pdf_file}")
            fail_count += 1

    except Exception as e:
        print(f"✗ Error processing {pdf_file}: {e}")
        fail_count += 1

# === Summary ===
print("\n=== Summary ===")
print(f"Total PDFs found: {len([f for f in os.listdir(PDF_FOLDER) if f.lower().endswith('.pdf')])}")
print(f"Converted: {success_count}")
print(f"Failed: {fail_count}")
print(f"Skipped (already exists): {skipped_count}")
# Out:
# Converting 10.1002_2017jc013030.pdf...
# ✓ Success: 10.1002_2017jc013030.pdf
# Converting 10.1002_anie.201916483.pdf...
# ✓ Success: 10.1002_anie.201916483.pdf
# Converting 10.1002_anie.202005531.pdf...
# ✓ Success: 10.1002_anie.202005531.pdf
# Converting 10.1002_anie.202007717.pdf...
# ✓ Success: 10.1002_anie.202007717.pdf
# Converting 10.1002_chem.201902131.pdf...
# ✓ Success: 10.1002_chem.201902131.pdf
# Converting 10.1002_chem.201903120.pdf...
# ✓ Success: 10.1002_chem.201903120.pdf
# Converting 10.1002_chem.202000235.pdf...
# ✓ Success: 10.1002_chem.202000235.pdf
# Converting 10.1002_chem.202001412.pdf...
# ✓ Success: 10.1002_chem.202001412.pdf
# Converting 10.1002_chem.202001668.pdf...
# ✓ Success: 10.1002_chem.202001668.pdf
# Converting 10.1002_chem.202003167.pdf...
# ✓ Success: 10.1002_chem.202003167.pdf
# Converting 10.1002_cssc.202201821.pdf...
# ✓ Success: 10.1002_cssc.202201821.pdf
# Converting 10.1002_ece3.3985.pdf...
# ✓ Success: 10.1002_ece3.3985.pdf
# Converting 10.1002_ece3.4466.pdf...
# ✓ Success: 10.1002_ece3.4466.pdf
# Converting 10.1002_ece3.5260.pdf...
# ✓ Success: 10.1002_ece3.5260.pdf
# Converting 10.1002_ece3.5395.pdf...
# ✓ Success: 10.1002_ece3.5395.pdf
# Converting 10.1002_ece3.6144.pdf...
# ✓ Success: 10.1002_ece3.6144.pdf
# Converting 10.1002_ece3.6303.pdf...
# ✓ Success: 10.1002_ece3.6303.pdf
# Converting 10.1002_ece3.6784.pdf...
# ✓ Success: 10.1002_ece3.6784.pdf
# Converting 10.1002_ece3.961.pdf...
# ✓ Success: 10.1002_ece3.961.pdf
# Converting 10.1002_ece3.9627.pdf...
# ✓ Success: 10.1002_ece3.9627.pdf
# Converting 10.1002_ecs2.1280.pdf...
# ✓ Success: 10.1002_ecs2.1280.pdf
# Converting 10.1002_ecs2.4619.pdf...
# ✓ Success: 10.1002_ecs2.4619.pdf
# Converting 10.1002_ejic.201900904.pdf...
# ✓ Success: 10.1002_ejic.201900904.pdf
# Converting 10.1002_ejoc.202000139.pdf...
# ✓ Success: 10.1002_ejoc.202000139.pdf
# Converting 10.1002_ejoc.202000916.pdf...
# ✓ Success: 10.1002_ejoc.202000916.pdf
# Converting 10.1002_esp.5058.pdf...
# ✓ Success: 10.1002_esp.5058.pdf
# Converting 10.1002_esp.5090.pdf...
# ✓ Success: 10.1002_esp.5090.pdf
# Converting 10.1002_mp.14424.pdf...
# ✓ Success: 10.1002_mp.14424.pdf
# Converting 10.1002_nafm.10870.pdf...
# ✓ Success: 10.1002_nafm.10870.pdf
# Converting 10.1007_jhep07(2018)134.pdf...
# ✓ Success: 10.1007_jhep07(2018)134.pdf
#
# === Summary ===
# Total PDFs found: 30
# Converted: 30
# Failed: 0
# Skipped (already exists): 0

# %% [markdown]
# XML TO JSON FILE

# %%
import os
import xmltodict
import json

# === Configuration ===
xml_folder = r"make-data-count-finding-data-references\test\ALL_XML"
json_folder = r"make-data-count-finding-data-references\test\all_json_files"

# === Ensure output folder exists ===
os.makedirs(json_folder, exist_ok=True)

# === Process each XML file ===
converted = 0
failed = 0

for filename in os.listdir(xml_folder):
    if not filename.lower().endswith(".xml"):
        continue

    xml_path = os.path.join(xml_folder, filename)
    json_filename = os.path.splitext(filename)[0] + ".json"
    json_path = os.path.join(json_folder, json_filename)

    try:
        with open(xml_path, 'r', encoding='utf-8') as xml_file:
            xml_content = xml_file.read()
            data_dict = xmltodict.parse(xml_content)

        with open(json_path, 'w', encoding='utf-8') as json_file:
            json.dump(data_dict, json_file, indent=2)

        print(f"✓ Converted: {filename}")
        converted += 1

    except Exception as e:
        print(f"✗ Failed to convert {filename}: {e}")
        failed += 1

# === Summary ===
print("\n=== Conversion Summary ===")
print(f"Total XML files: {converted + failed}")
print(f"Converted successfully: {converted}")
print(f"Failed: {failed}")
# Out:
# ✓ Converted: 10.1002_2017jc013030.xml
# ✓ Converted: 10.1002_anie.201916483.xml
# ✓ Converted: 10.1002_anie.202005531.xml
# ✓ Converted: 10.1002_anie.202007717.xml
# ✓ Converted: 10.1002_chem.201902131.xml
# ✓ Converted: 10.1002_chem.201903120.xml
# ✓ Converted: 10.1002_chem.202000235.xml
# ✓ Converted: 10.1002_chem.202001412.xml
# ✓ Converted: 10.1002_chem.202001668.xml
# ✓ Converted: 10.1002_chem.202003167.xml
# ✓ Converted: 10.1002_cssc.202201821.xml
# ✓ Converted: 10.1002_ece3.3985.xml
# ✓ Converted: 10.1002_ece3.4466.xml
# ✓ Converted: 10.1002_ece3.5260.xml
# ✓ Converted: 10.1002_ece3.5395.xml
# ✓ Converted: 10.1002_ece3.6144.xml
# ✓ Converted: 10.1002_ece3.6303.xml
# ✓ Converted: 10.1002_ece3.6784.xml
# ✓ Converted: 10.1002_ece3.961.xml
# ✓ Converted: 10.1002_ece3.9627.xml
# ✓ Converted: 10.1002_ecs2.1280.xml
# ✓ Converted: 10.1002_ecs2.4619.xml
# ✓ Converted: 10.1002_ejic.201900904.xml
# ✓ Converted: 10.1002_ejoc.202000139.xml
# ✓ Converted: 10.1002_ejoc.202000916.xml
# ✓ Converted: 10.1002_esp.5058.xml
# ✓ Converted: 10.1002_esp.5090.xml
# ✓ Converted: 10.1002_mp.14424.xml
# ✓ Converted: 10.1002_nafm.10870.xml
# ✓ Converted: 10.1007_jhep07(2018)134.xml
#
# === Conversion Summary ===
# Total XML files: 30
# Converted successfully: 30
# Failed: 0

# %% [markdown]
# REGEX PATTERN FOR TEST DATASET

# %%
import os
import json
import re
import pandas as pd
from nltk.tokenize import sent_tokenize
from tqdm import tqdm

# === Paths ===
JSON_DIR = r"make-data-count-finding-data-references/test/all_json_files"

# === Dataset Regex Patterns ===
DATASET_PATTERNS = [
    r'10\.\d{4,9}/[-._;()/:a-z0-9]+',       # DOIs
    r'doi:10\.\d{4,9}/[-._;()/:a-z0-9]+',   # doi: prefix
    r'\bgse\d{4,6}\b', r'\bsrp\d+\b', r'\bsrx\d+\b', r'\bsrr\d+\b', r'\berr\d+\b',
    r'\bdrr\d+\b', r'\be-mexp-\d+\b', r'\be-geod-\d+\b',
    r'\bens[a-z]{0,5}\d+\b', r'\bnm_\d+\b', r'\brs\d+\b',
    r'\bhgnc:\d+\b', r'\b[opq][0-9][a-z0-9]{3}[0-9]\b',
    r'\bmodel\d+\b', r'\bepi_isl_\d+\b', r'\bchembl\d+\b', r'\bmgyp\d+\b',
    r'\bempiar-?\d+\b', r'\bprjna\d+\b', r'\bsamn\d+\b', r'\bpxd\d+\b',
    r'\bku\d+\b', r'\bcvcl_\d+\b', r'\bcab\d+\b', r'\bhpa\d+\b',
    r'\be-prot-\d+\b',
    r'\b[A-Z]{1,2}\d{6}(?:\.\d+)?\b',       # GenBank accessions (e.g., MH714866)
    r'\b\d+\.\d+\.\d+\.\d+\b'               # IP-like or version numbers
]
regex_combined = re.compile("|".join(DATASET_PATTERNS), re.IGNORECASE)

# === Dataset-related keywords
DATASET_KEYWORDS = [
    "dataset", "data available", "accession number", "repository",
    "deposited", "submitted to", "released", "archive", "downloaded from",
    "data were deposited", "data can be accessed", "hosted in", "publicly available"
]

def contains_keyword(text):
    text = text.lower()
    return any(keyword in text for keyword in DATASET_KEYWORDS)

# === Pre-clean broken patterns like `doi. org` → `doi.org`
def clean_text(text):
    text = re.sub(r'doi\s*\.\s*org', 'doi.org', text, flags=re.IGNORECASE)
    text = re.sub(r'https?\s*:\s*/\s*/\s*doi\s*\.\s*org', 'https://doi.org', text, flags=re.IGNORECASE)
    text = re.sub(r'10\s*\.\s*(\d+)', r'10.\1', text)
    return text

# === Extract all string values recursively from JSON
def extract_strings_from_json(obj):
    if isinstance(obj, dict):
        for v in obj.values():
            yield from extract_strings_from_json(v)
    elif isinstance(obj, list):
        for item in obj:
            yield from extract_strings_from_json(item)
    elif isinstance(obj, str):
        yield obj

# === Filtering Function for Invalid Matches
def is_valid_dataset_id(match, sentence):
    if re.fullmatch(r"(19|20)\d{2}", match):  # year
        return False
    if re.fullmatch(r"\d+\.\d+\.\d+\.\d+", match):  # IP or version
        if re.search(r"(v|version)[\s:=]*" + re.escape(match), sentence, re.IGNORECASE):
            return False
    if match.isdigit() and len(match) <= 3:
        return False
    if re.fullmatch(r"\d{4}-\d{2}-\d{2}", match):  # date
        return False
    return True

# === Main Dataset Detection
results = []

for filename in tqdm(os.listdir(JSON_DIR)):
    if not filename.endswith(".json"):
        continue
    path = os.path.join(JSON_DIR, filename)
    article_id = filename.replace(".json", "")

    try:
        with open(path, "r", encoding="utf-8") as f:
            data = json.load(f)
    except Exception as e:
        print(f"❌ Error in {filename}: {e}")
        continue

    all_strings = list(extract_strings_from_json(data))

    for raw_text in all_strings:
        cleaned_text = clean_text(raw_text)
        for sent in sent_tokenize(cleaned_text):
            matches = regex_combined.findall(sent)
            valid_matches = [m for m in matches if is_valid_dataset_id(m, sent)]
            if valid_matches:
                results.append({
                    "article_id": article_id,
                    "sentence": sent.strip(),
                    "dataset_id": "; ".join(sorted(set(valid_matches)))
                })

# === Save to CSV
df = pd.DataFrame(results)
df.to_csv("dataset_mentions_test.csv", index=False)
print(f"✅ Extracted {len(df)} dataset sentences after filtering. Saved to dataset_mentions_test.csv")
# Out:
# 100%|██████████| 30/30 [00:02<00:00, 10.58it/s]
# ✅ Extracted 2092 dataset sentences after filtering. Saved to dataset_mentions_test.csv
